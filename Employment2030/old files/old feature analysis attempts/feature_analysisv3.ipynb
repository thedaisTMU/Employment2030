# %%
def tree_paths(tree):
    
    children_left = tree.children_left
    children_right = tree.children_right
    values = tree.value
    
    tree_paths = []
    tree_probs = []
    path = []
    path_probs = []
    stack = [(0, -1)]  # seed is the root node id and its parent depth
    while len(stack) > 0:
        node_id, parent_depth = stack.pop()    
               
        while len(path)>parent_depth+1:
            path.pop()
            path_probs.pop()
        path.append(node_id)
        true = values[node_id][0][0].copy()
        false = values[node_id][0][1].copy()
        path_probs.append(round(true/(true+false),3))
        
        # If we have a test node
        if (children_left[node_id] != children_right[node_id]):
            stack.append((children_left[node_id], parent_depth + 1))
            stack.append((children_right[node_id], parent_depth + 1))
        else:
            tree_paths.append(path.copy())
            tree_probs.append(path_probs.copy())
            
    return tree_paths, tree_probs

# %%
def forest_paths(model):    
    forest_attributes = []
    baseline_means = []
    
    for treeEst in model.estimators_:
        path_thresholds = []
        path_features = []
        path_probs = []
        
        children_left = treeEst.tree_.children_left
        children_right = treeEst.tree_.children_right
        all_thresholds = treeEst.tree_.threshold
        all_features = treeEst.tree_.feature

        paths, path_probs = tree_paths(treeEst.tree_)
        
        leaf_probs = []
        for prob_list in path_probs:
                leaf_probs.append(prob_list[len(prob_list)-1])
        baseline_means.append(np.mean(leaf_probs))

        for i in range(len(paths)):
            thresholds = []
            features = []
            for j in range(len(paths[i])-1):
                if paths[i][j+1] == children_right[paths[i][j]]:
                    thresholds.append(all_thresholds[paths[i][j]])
                else:
                    thresholds.append(-all_thresholds[paths[i][j]])
                features.append(all_features[paths[i][j]])
            path_thresholds.append(thresholds.copy())
            path_features.append(features.copy())
    
        tree_atributes = pd.DataFrame([path_features, path_thresholds, path_probs]).T
        tree_atributes.columns = ['features','thresholds','path_probs']
        forest_attributes.append(tree_atributes.copy())
    return forest_attributes, np.mean(baseline_means)

# %%
def init_influence_list(features,conditionals,product):
    if product:
        combo_index = pd.MultiIndex.from_product([features,conditionals])
    else:
        combo_index = pd.MultiIndex.from_arrays([features,conditionals])
    
    infl_lists = []
    for i in range(combo_index.to_series().shape[0]):
        infl_lists.append([])
    
    influences = pd.Series(infl_lists,index=combo_index)
    
    return influences

# %%
def get_influences(feature_combos,model):
    forest_attributes, baseline = forest_paths(model)
    
    for tree_frame in forest_attributes:
        for index, path in tree_frame.iterrows():
            previous = ['blank']
            for step in range(len(path['features'])-1):
                #what features we have seen and the feature we are on
                current_feature = path['features'][step]
                direction = np.sign(path['thresholds'][step])
                if current_feature in feature_combos.index.get_level_values(0):
                    #make relevant calculations
                    current_prob = path['path_probs'][step]
                    next_prob = path['path_probs'][step+1]
                    pct_change = (next_prob-current_prob)/current_prob
                    influence = direction*pct_change
                    #add to all relevant combos
                    for combo in feature_combos.loc[current_feature,previous]:
                        combo.append(influence)
                previous.append(current_feature*direction)
                
    influences_df = pd.DataFrame(index=feature_combos.index)
    
    for index, influences in feature_combos.iteritems():
        if influences:
            influences = np.asarray(influences)
            influences_df.loc[index,'pos_influence'] = np.mean(influences[influences>0])
            influences_df.loc[index,'neg_influence'] = np.mean(influences[influences<=0])
            influences_df.loc[index,'pct_pos'] = np.sum(influences>0)/len(influences)
            influences_df.loc[index,'occurance count'] = len(influences)
    return influences_df

# %%
def feature_name_index(table,features):
    
    conditional_labels = []#I know there is a better way to do this
    for condition in table.index.get_level_values(1):
        if condition == 'blank':
            conditional_labels.append(condition)
        elif condition >=0:
            conditional_labels.append("high "+features[condition])
        else:
            conditional_labels.append("low "+features[-1*condition])
    
    table_index = pd.MultiIndex.from_arrays([
        features[table.index.get_level_values(0)],conditional_labels])

    table.index = table_index
    
    return table

# %%
# %run ../utils_rf

# %%
#read training data
file = "../../../tables/model_input/noc_answers.csv"
x, x_agg, y, y_agg, x_noclvl, y_noclvl = data_proccess(file,True)
x.drop(['work_num_1','work_num_2','work_num_3','work_num_4','work_num_5','work_num_6'],axis=1,inplace=True)

#grab just the noc codes to cut out test nocs from main noc table
train_nocs = pd.read_csv(file,usecols=['noc_code']).drop_duplicates()

# %%
rf = RandomForestClassifier(**init_params('cat'))
rf.fit(x,y['increase'])

#rf_dec = RandomForestClassifier(**init_params('cat'))
#rf_dec.fit(x,y['decrease'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=8, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=250, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf_features = pd.Series(rf.feature_importances_,index=x.columns)
selected_features = rf_features.sort_values(ascending=False).iloc[0:20]
selected_features_ix = np.where(np.isin(x.columns,selected_features.index))[0]
selected_features = x.columns[selected_features_ix]

# %%
#analsysis of non SFFS increase and decrease models
#making combo sets to check
conditionals = list(range(120))+list(range(-119,0))+['blank']
all_combos = init_influence_list(range(120),conditionals,True)

#running the analysis
influences = feature_name_index(get_influences(all_combos,rf),x.columns)
# dec_influences = feature_name_index(get_influences(all_combos,rf_dec),x.columns)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-f045fe9170b2>", line 7, in <module>
#     influences = feature_name_index(get_influences(all_combos,rf),x.columns)
#   File "<ipython-input-4-48b757171b47>", line 11, in get_influences
#     if current_feature in feature_combos.index.get_level_values(0):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\numeric.py", line 180, in __contains__
#     return key in self._engine
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
# AttributeError: module has no attribute '__name__'
# ---------------------------------------------------------------------------

# %%
#SFFS structual analsysis
sffs_conditionals = list(range(0,13))+list(range(-13,0))+['blank']
sffs_combos = init_influence_list(range(0,13),sffs_conditionals,True)
sffs_influences = feature_name_index(get_influences(sffs_combos,rf_sffs),x_sffs.columns)

# %%
non_cond_inf = influences.xs('blank',level=1)
non_cond_inf.loc[non_cond_inf['pct_pos']>0.95]
# Out:
#                            pos_influence  neg_influence   pct_pos  \
# value.Persuasion                0.379083      -0.153903  0.961930
# value.Instructing               0.319096      -0.145940  0.962264
# value.Service Orientation       0.298379      -0.160304  0.960057
# value.Systems Evaluation        0.341401      -0.116726  0.970628
# value.Fluency of Ideas          0.406025      -0.128103  0.980210
# value.Originality               0.347700      -0.156877  0.956120
# value.Memorization              0.303741      -0.139704  0.989091
# value.Fine Arts                 0.149403      -0.064652  0.959016
#
#                            occurance count
# value.Persuasion                    1865.0
# value.Instructing                    901.0
# value.Service Orientation           1402.0
# value.Systems Evaluation            1464.0
# value.Fluency of Ideas              1617.0
# value.Originality                   1299.0
# value.Memorization                  1375.0
# value.Fine Arts                      366.0

# %%
non_cond_inf_dec = dec_influences.xs('blank',level=1)
non_cond_inf_dec.loc[non_cond_inf_dec['pct_pos']>0.8]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e81f5b58ea51> in <module>
# ----> 1 non_cond_inf_dec = dec_influences.xs('blank',level=1)
#       2 non_cond_inf_dec.loc[non_cond_inf_dec['pct_pos']>0.8]
#
# NameError: name 'dec_influences' is not defined

# %%
#getting portions instead of path counts
influences = pd.merge(influences.reset_index(),
      non_cond_inf['occurance count'].reset_index(),
      left_on=['level_0'],
      right_on=['index'],
      how='inner').set_index(['level_0','level_1']).drop('index',axis=1)

influences['occurance pct'] = influences['occurance count_x']/influences['occurance count_y']

# %% [markdown]
# Ok we need to check for consistency here

# %%
top10set = []
for i in range(10):
    rf = RandomForestClassifier(**init_params('cat')).fit(x,y['increase'])
    conditionals = list(range(120))+list(range(-119,0))+['blank']
    all_combos = init_influence_list(range(120),conditionals,True)
    influences = feature_name_index(get_influences(all_combos,rf),x.columns)
    non_cond_info = influences.xs('blank',level=1)
    top10set.append(non_cond_info.loc[non_cond_info['pct_pos']>0.95].copy())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
top10Decset = []
for i in range(10):
    rf_dec = RandomForestClassifier(**init_params('cat')).fit(x,y['decrease'])
    conditionals = list(range(120))+list(range(-119,0))+['blank']
    all_combos = init_influence_list(range(120),conditionals,True)
    influences = feature_name_index(get_influences(all_combos,rf_dec),x.columns)
    non_cond_inf = influences.xs('blank',level=1)
    top10Decset.append(non_cond_inf.loc[non_cond_inf['pct_pos']>0.95].copy())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fullset = []
for bestset in top10set:
    fullset.append(bestset.index.get_values())

# %%
full_dec_set = []
for bestset in top10Decset:
    full_dec_set.append(bestset.index.get_values())

# %%
cons_set = np.unique(np.concatenate(fullset),return_counts =True)

# %%
cons_dec_set = np.unique(np.concatenate(full_dec_set),return_counts =True)

# %%
pd.DataFrame({'SAK':cons_dec_set[0],'count':cons_dec_set[1]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-077d3d06de46> in <module>
# ----> 1 pd.DataFrame({'SAK':cons_dec_set[0],'count':cons_dec_set[1]})
#
# NameError: name 'cons_dec_set' is not defined

# %%
over09 = pd.DataFrame({'SAK':cons_set[0],'count':cons_set[1]})
over09.loc[over09['count']>=5]
# Out:
#                                     SAK  count
# 0                value.Active Listening      8
# 1   value.Customer and Personal Service      8
# 6                       value.Fine Arts      6
# 7                value.Fluency of Ideas     10
# 8                    value.Installation      8
# 9                     value.Instructing     10
# 12                   value.Memorization     10
# 13                value.Number Facility      7
# 14                    value.Originality     10
# 15                     value.Persuasion     10
# 16        value.Philosophy and Theology      7
# 17            value.Service Orientation     10
# 18               value.Systems Analysis      9
# 19             value.Systems Evaluation     10
# 20              value.Technology Design     10
# 21                  value.Visualization      9

# %% [markdown]
# analysis of thresholds

# %%
paths = pd.concat(forest_paths(rf)[0])

# %%
thresholds = np.empty([2,0])

for index, path in paths.iterrows():
    thresholds = np.append(
        thresholds,
        np.vstack([path['features'],path['thresholds']]),
        axis=1
    )
thresholds = pd.DataFrame({'feature':thresholds[0],'threshold':thresholds[1]})

# %%
np.where(x.columns == 'value.Technology Design')
# Out:
# (array([18]),)

# %%
thresh_portion = pd.DataFrame(
    np.unique(abs(thresholds.loc[thresholds['feature']==18]['threshold']),return_counts = True)
).T
thresh_portion['pct']=thresh_portion[1]/np.sum(thresh_portion[1])
thresh_portion.sort_values('pct',ascending=False)
# Out:
#      0      1       pct
# 2  2.5  685.0  0.610517
# 0  1.5  435.0  0.387701
# 1  2.0    2.0  0.001783

# %% [markdown]
# Conditionals

# %%
# again we need shit to be consitent so we run 10 times and take averages
for i in range(10):
    rf = RandomForestClassifier(**init_params('cat')).fit(x,y['increase'])
    conditionals = list(range(120))+list(range(-119,0))+['blank']
    all_combos = init_influence_list(range(120),conditionals,True)
    current_infl = feature_name_index(get_influences(all_combos,rf),x.columns).fillna(0)

    pairs = current_infl[
    np.logical_not(
        np.in1d(current_infl.index.get_level_values(1), 'blank')
    )].copy()
    
    current_sig_pairs = pairs.loc[np.logical_or(pairs['pct_pos']>0.95,pairs['pct_pos']<0.05)].copy()
    current_sig_pairs['count']=1
    if i==0:
        sig_pairs = current_sig_pairs
    else:
        common_idx = sig_pairs.index.intersection(current_sig_pairs.index) #grab the pair we have seen
        for_update = sig_pairs.loc[common_idx,sig_pairs.columns != 'count'].copy()#make lists of old and new info
        update_with = current_sig_pairs.loc[common_idx,sig_pairs.columns != 'count'].copy()
        new_pairs = current_sig_pairs.loc[~current_sig_pairs.index.isin(common_idx)].copy()#new rows
        counts = sig_pairs.loc[common_idx,'count'].copy()
        updated  = (for_update.mul(counts,axis=0).add(update_with,axis=0)).div(counts+1,axis=0)
        
        sig_pairs.loc[common_idx,sig_pairs.columns != 'count'] = updated.copy()
        sig_pairs.loc[common_idx,'count'] = sig_pairs.loc[common_idx,'count']+1
        sig_pairs = pd.concat([sig_pairs,new_pairs])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
#define signficance markers based on how many times we ran everything
sig_pairs['significance'] = 'not sig'
sig_pairs.loc[sig_pairs['count']>i/4,'significance'] = '*'
sig_pairs.loc[sig_pairs['count']>2*i/4,'significance'] = '**'
sig_pairs.loc[sig_pairs['count']>3*i/4,'significance'] = '***'
sig_pairs = sig_pairs.loc[sig_pairs['significance']!='not sig']

# %%
law_pairs = sig_pairs.loc[sig_pairs.index.get_level_values(0).str.contains('Law')]
neg_law_pairs = law_pairs.loc[law_pairs['pct_pos']<0.05]
neg_law_pairs = neg_law_pairs.loc[neg_law_pairs.index.get_level_values(1).str.contains('low')]
neg_law_pairs.loc[np.logical_or(neg_law_pairs['significance']=='***',
                                neg_law_pairs['significance']=='**')].sort_values('neg_influence')
# Out:
#                                                                       pos_influence  \
# main                     conditional
# value.Law and Government low value.Arm-Hand Steadiness                     0.000000
#                          low value.Education and Training                  0.000000
#                          low value.Technology Design                       0.224463
#                          low value.Dynamic Strength                        0.000000
#                          low value.Auditory Attention                      0.000000
#                          low value.Administration and Management           0.000000
#                          low value.Rate Control                            0.070652
#                          low value.Clerical                                0.005042
#                          low value.Operation Monitoring                    0.008258
#                          low value.Operation and Control                   0.000000
#                          low value.Control Precision                       0.000000
#                          low value.Trunk Strength                          0.000000
#                          low value.Biology                                 0.000000
#                          low value.Spatial Orientation                     0.000000
#                          low value.Economics and Accounting                0.000000
#                          low value.Sound Localization                      0.000000
#                          low value.Near Vision                             0.000000
#                          low value.Depth Perception                        0.000000
#                          low value.Monitoring                              0.000000
#                          low value.Response Orientation                    0.000000
#                          low value.Equipment Maintenance                   0.000000
#                          low value.Judgment and Decision Making            0.000000
#                          low value.Category Flexibility                    0.000000
#                          low value.Sales and Marketing                     0.000000
#                          low value.Management of Financial Resources       0.000000
#                          low value.Speaking                                0.000000
#                          low value.Coordination                            0.000000
#                          low value.Writing                                 0.000000
#                          low value.Selective Attention                     0.000000
#
#                                                                       neg_influence  \
# main                     conditional
# value.Law and Government low value.Arm-Hand Steadiness                    -0.243251
#                          low value.Education and Training                 -0.191440
#                          low value.Technology Design                      -0.183386
#                          low value.Dynamic Strength                       -0.174063
#                          low value.Auditory Attention                     -0.171301
#                          low value.Administration and Management          -0.166898
#                          low value.Rate Control                           -0.161239
#                          low value.Clerical                               -0.154846
#                          low value.Operation Monitoring                   -0.150420
#                          low value.Operation and Control                  -0.140369
#                          low value.Control Precision                      -0.132066
#                          low value.Trunk Strength                         -0.121581
#                          low value.Biology                                -0.102434
#                          low value.Spatial Orientation                    -0.078620
#                          low value.Economics and Accounting               -0.074586
#                          low value.Sound Localization                     -0.069981
#                          low value.Near Vision                            -0.069504
#                          low value.Depth Perception                       -0.055102
#                          low value.Monitoring                             -0.050495
#                          low value.Response Orientation                   -0.046892
#                          low value.Equipment Maintenance                  -0.040476
#                          low value.Judgment and Decision Making           -0.034076
#                          low value.Category Flexibility                   -0.032650
#                          low value.Sales and Marketing                    -0.029690
#                          low value.Management of Financial Resources      -0.023103
#                          low value.Speaking                               -0.021836
#                          low value.Coordination                           -0.008170
#                          low value.Writing                                -0.008016
#                          low value.Selective Attention                     0.000000
#
#                                                                        pct_pos  \
# main                     conditional
# value.Law and Government low value.Arm-Hand Steadiness                0.000000
#                          low value.Education and Training             0.000000
#                          low value.Technology Design                  0.026950
#                          low value.Dynamic Strength                   0.000000
#                          low value.Auditory Attention                 0.000000
#                          low value.Administration and Management      0.000000
#                          low value.Rate Control                       0.006667
#                          low value.Clerical                           0.009091
#                          low value.Operation Monitoring               0.004938
#                          low value.Operation and Control              0.000000
#                          low value.Control Precision                  0.000000
#                          low value.Trunk Strength                     0.000000
#                          low value.Biology                            0.000000
#                          low value.Spatial Orientation                0.000000
#                          low value.Economics and Accounting           0.000000
#                          low value.Sound Localization                 0.000000
#                          low value.Near Vision                        0.000000
#                          low value.Depth Perception                   0.000000
#                          low value.Monitoring                         0.000000
#                          low value.Response Orientation               0.000000
#                          low value.Equipment Maintenance              0.000000
#                          low value.Judgment and Decision Making       0.000000
#                          low value.Category Flexibility               0.000000
#                          low value.Sales and Marketing                0.000000
#                          low value.Management of Financial Resources  0.000000
#                          low value.Speaking                           0.000000
#                          low value.Coordination                       0.000000
#                          low value.Writing                            0.000000
#                          low value.Selective Attention                0.000000
#
#                                                                       occurance count  \
# main                     conditional
# value.Law and Government low value.Arm-Hand Steadiness                       4.000000
#                          low value.Education and Training                   11.166667
#                          low value.Technology Design                       100.000000
#                          low value.Dynamic Strength                         21.200000
#                          low value.Auditory Attention                       18.800000
#                          low value.Administration and Management            16.111111
#                          low value.Rate Control                             19.833333
#                          low value.Clerical                                 34.400000
#                          low value.Operation Monitoring                     17.333333
#                          low value.Operation and Control                    15.333333
#                          low value.Control Precision                         9.571429
#                          low value.Trunk Strength                            2.857143
#                          low value.Biology                                   8.400000
#                          low value.Spatial Orientation                       7.142857
#                          low value.Economics and Accounting                  5.875000
#                          low value.Sound Localization                        5.500000
#                          low value.Near Vision                               5.000000
#                          low value.Depth Perception                          0.200000
#                          low value.Monitoring                                4.714286
#                          low value.Response Orientation                      1.400000
#                          low value.Equipment Maintenance                     3.285714
#                          low value.Judgment and Decision Making              1.333333
#                          low value.Category Flexibility                      1.600000
#                          low value.Sales and Marketing                       1.666667
#                          low value.Management of Financial Resources         1.400000
#                          low value.Speaking                                  0.500000
#                          low value.Coordination                              0.444444
#                          low value.Writing                                   1.250000
#                          low value.Selective Attention                       0.000000
#
#                                                                       count  \
# main                     conditional
# value.Law and Government low value.Arm-Hand Steadiness                    9
#                          low value.Education and Training                 6
#                          low value.Technology Design                      6
#                          low value.Dynamic Strength                       5
#                          low value.Auditory Attention                     5
#                          low value.Administration and Management          9
#                          low value.Rate Control                           6
#                          low value.Clerical                               5
#                          low value.Operation Monitoring                   9
#                          low value.Operation and Control                  6
#                          low value.Control Precision                      7
#                          low value.Trunk Strength                         7
#                          low value.Biology                                5
#                          low value.Spatial Orientation                    7
#                          low value.Economics and Accounting               8
#                          low value.Sound Localization                     8
#                          low value.Near Vision                            8
#                          low value.Depth Perception                      10
#                          low value.Monitoring                             7
#                          low value.Response Orientation                   5
#                          low value.Equipment Maintenance                  7
#                          low value.Judgment and Decision Making           9
#                          low value.Category Flexibility                  10
#                          low value.Sales and Marketing                    6
#                          low value.Management of Financial Resources     10
#                          low value.Speaking                              10
#                          low value.Coordination                           9
#                          low value.Writing                                8
#                          low value.Selective Attention                   10
#
#                                                                      significance
# main                     conditional
# value.Law and Government low value.Arm-Hand Steadiness                        ***
#                          low value.Education and Training                      **
#                          low value.Technology Design                           **
#                          low value.Dynamic Strength                            **
#                          low value.Auditory Attention                          **
#                          low value.Administration and Management              ***
#                          low value.Rate Control                                **
#                          low value.Clerical                                    **
#                          low value.Operation Monitoring                       ***
#                          low value.Operation and Control                       **
#                          low value.Control Precision                          ***
#                          low value.Trunk Strength                             ***
#                          low value.Biology                                     **
#                          low value.Spatial Orientation                        ***
#                          low value.Economics and Accounting                   ***
#                          low value.Sound Localization                         ***
#                          low value.Near Vision                                ***
#                          low value.Depth Perception                           ***
#                          low value.Monitoring                                 ***
#                          low value.Response Orientation                        **
#                          low value.Equipment Maintenance                      ***
#                          low value.Judgment and Decision Making               ***
#                          low value.Category Flexibility                       ***
#                          low value.Sales and Marketing                         **
#                          low value.Management of Financial Resources          ***
#                          low value.Speaking                                   ***
#                          low value.Coordination                               ***
#                          low value.Writing                                    ***
#                          low value.Selective Attention                        ***

# %%
comp_pairs = sig_pairs.loc[sig_pairs.index.get_level_values(0).str.contains('Computers')]
neg_comp_pairs = comp_pairs.loc[comp_pairs['pct_pos']<0.05]
neg_comp_pairs = neg_comp_pairs.loc[neg_comp_pairs.index.get_level_values(1).str.contains('low')]
neg_comp_pairs.loc[np.logical_or(neg_comp_pairs['significance']=='***',
                                neg_comp_pairs['significance']=='**')].sort_values('neg_influence')
# Out:
#                                                                             pos_influence  \
# main                            conditional
# value.Computers and Electronics low value.Speech Clarity                         0.000000
#                                 low value.Originality                            0.011905
#                                 low value.Systems Evaluation                     0.035805
#                                 low value.Active Listening                       0.038627
#                                 low value.History and Archeology                 0.000000
#                                 low value.Communications and Media               0.000000
#                                 low value.Speed of Limb Movement                 0.000000
#                                 low value.Oral Comprehension                     0.000000
#                                 low value.Science                                0.000000
#                                 low value.Equipment Selection                    0.000000
#                                 low value.Writing                                0.000000
#                                 low value.Management of Material Resources       0.000000
#                                 low value.Written Comprehension                  0.000000
#                                 low value.Peripheral Vision                      0.000000
#
#                                                                             neg_influence  \
# main                            conditional
# value.Computers and Electronics low value.Speech Clarity                        -0.442977
#                                 low value.Originality                           -0.429434
#                                 low value.Systems Evaluation                    -0.390503
#                                 low value.Active Listening                      -0.389307
#                                 low value.History and Archeology                -0.200634
#                                 low value.Communications and Media              -0.179919
#                                 low value.Speed of Limb Movement                -0.161550
#                                 low value.Oral Comprehension                    -0.129044
#                                 low value.Science                               -0.127272
#                                 low value.Equipment Selection                   -0.072148
#                                 low value.Writing                               -0.058950
#                                 low value.Management of Material Resources      -0.056564
#                                 low value.Written Comprehension                 -0.040938
#                                 low value.Peripheral Vision                     -0.022250
#
#                                                                              pct_pos  \
# main                            conditional
# value.Computers and Electronics low value.Speech Clarity                    0.000000
#                                 low value.Originality                       0.007843
#                                 low value.Systems Evaluation                0.014378
#                                 low value.Active Listening                  0.007576
#                                 low value.History and Archeology            0.000000
#                                 low value.Communications and Media          0.000000
#                                 low value.Speed of Limb Movement            0.000000
#                                 low value.Oral Comprehension                0.000000
#                                 low value.Science                           0.000000
#                                 low value.Equipment Selection               0.000000
#                                 low value.Writing                           0.000000
#                                 low value.Management of Material Resources  0.000000
#                                 low value.Written Comprehension             0.000000
#                                 low value.Peripheral Vision                 0.000000
#
#                                                                             occurance count  \
# main                            conditional
# value.Computers and Electronics low value.Speech Clarity                          18.800000
#                                 low value.Originality                             55.200000
#                                 low value.Systems Evaluation                      39.166667
#                                 low value.Active Listening                        23.000000
#                                 low value.History and Archeology                  12.875000
#                                 low value.Communications and Media                 5.500000
#                                 low value.Speed of Limb Movement                   4.777778
#                                 low value.Oral Comprehension                       1.900000
#                                 low value.Science                                  7.750000
#                                 low value.Equipment Selection                      3.142857
#                                 low value.Writing                                  2.333333
#                                 low value.Management of Material Resources         2.111111
#                                 low value.Written Comprehension                    0.400000
#                                 low value.Peripheral Vision                        0.600000
#
#                                                                             count  \
# main                            conditional
# value.Computers and Electronics low value.Speech Clarity                        5
#                                 low value.Originality                           5
#                                 low value.Systems Evaluation                    6
#                                 low value.Active Listening                      6
#                                 low value.History and Archeology                8
#                                 low value.Communications and Media              6
#                                 low value.Speed of Limb Movement                9
#                                 low value.Oral Comprehension                   10
#                                 low value.Science                               8
#                                 low value.Equipment Selection                   7
#                                 low value.Writing                               6
#                                 low value.Management of Material Resources      9
#                                 low value.Written Comprehension                10
#                                 low value.Peripheral Vision                    10
#
#                                                                            significance
# main                            conditional
# value.Computers and Electronics low value.Speech Clarity                             **
#                                 low value.Originality                                **
#                                 low value.Systems Evaluation                         **
#                                 low value.Active Listening                           **
#                                 low value.History and Archeology                    ***
#                                 low value.Communications and Media                   **
#                                 low value.Speed of Limb Movement                    ***
#                                 low value.Oral Comprehension                        ***
#                                 low value.Science                                   ***
#                                 low value.Equipment Selection                       ***
#                                 low value.Writing                                    **
#                                 low value.Management of Material Resources          ***
#                                 low value.Written Comprehension                     ***
#                                 low value.Peripheral Vision                         ***

# %%
chem_pairs = sig_pairs.loc[sig_pairs.index.get_level_values(0).str.contains('Chemistry')]
neg_chem_pairs = chem_pairs.loc[chem_pairs['pct_pos']<0.05]
neg_chem_pairs = neg_chem_pairs.loc[neg_chem_pairs.index.get_level_values(1).str.contains('low')]
neg_chem_pairs.loc[np.logical_or(neg_chem_pairs['significance']=='***',
                                neg_chem_pairs['significance']=='**')].sort_values('neg_influence')
# Out:
#                                                   pos_influence  \
# main            conditional
# value.Chemistry low value.Number Facility              0.015057
#                 low value.Memorization                 0.043679
#                 low value.Psychology                   0.000000
#                 low value.Speech Clarity               0.000000
#                 low value.Deductive Reasoning          0.000000
#                 low value.Written Comprehension        0.000000
#                 low value.Mathematical Reasoning       0.000000
#                 low value.Speaking                     0.000000
#                 low value.Speech Recognition           0.000000
#                 low value.Oral Comprehension           0.000000
#                 low value.Written Expression           0.000000
#
#                                                   neg_influence   pct_pos  \
# main            conditional
# value.Chemistry low value.Number Facility             -0.286982  0.005319
#                 low value.Memorization                -0.216699  0.005871
#                 low value.Psychology                  -0.214948  0.000000
#                 low value.Speech Clarity              -0.088822  0.000000
#                 low value.Deductive Reasoning         -0.070255  0.000000
#                 low value.Written Comprehension       -0.059364  0.000000
#                 low value.Mathematical Reasoning      -0.055765  0.000000
#                 low value.Speaking                    -0.051684  0.000000
#                 low value.Speech Recognition          -0.047860  0.000000
#                 low value.Oral Comprehension          -0.032945  0.000000
#                 low value.Written Expression          -0.004848  0.000000
#
#                                                   occurance count  count  \
# main            conditional
# value.Chemistry low value.Number Facility                9.875000      8
#                 low value.Memorization                  41.000000      7
#                 low value.Psychology                     9.166667      6
#                 low value.Speech Clarity                 4.222222      9
#                 low value.Deductive Reasoning            5.222222      9
#                 low value.Written Comprehension          0.400000     10
#                 low value.Mathematical Reasoning         4.125000      8
#                 low value.Speaking                       0.700000     10
#                 low value.Speech Recognition             2.333333      9
#                 low value.Oral Comprehension             1.200000     10
#                 low value.Written Expression             0.200000     10
#
#                                                  significance
# main            conditional
# value.Chemistry low value.Number Facility                 ***
#                 low value.Memorization                    ***
#                 low value.Psychology                       **
#                 low value.Speech Clarity                  ***
#                 low value.Deductive Reasoning             ***
#                 low value.Written Comprehension           ***
#                 low value.Mathematical Reasoning          ***
#                 low value.Speaking                        ***
#                 low value.Speech Recognition              ***
#                 low value.Oral Comprehension              ***
#                 low value.Written Expression              ***

# %%
#name index levels
sig_pairs.index.set_names(['main','conditional'],inplace=True)

# %%
foundational = ['value.Fluency of Ideas', 'value.Memorization', 'value.Instructing', 
                'value.Persuasion','value.Service Orientation']

# %%
sig_pairs.to_csv('../../../tables/model_output/sig_pairs.csv')

# %%
sig_pairs = pd.read_csv('../../../tables/model_output/sig_pairs.csv',index_col=['main','conditional'])

# %% [markdown]
# Individual Pairings for in body examples

# %%
sig_pairs.xs('high value.Administration and Management',level=1).sort_values(['significance','pos_influence'],ascending=False)
# Out:
#                                          pos_influence  neg_influence  \
# main
# value.Memorization                            0.256990       0.000000
# value.Service Orientation                     0.234750      -0.004219
# value.Psychology                              0.177055       0.000000
# value.Fine Arts                               0.120420       0.000000
# value.Social Perceptiveness                   0.197264       0.000000
# value.Customer and Personal Service           0.195893       0.000000
# value.Chemistry                               0.188286      -0.007407
# value.Management of Material Resources        0.171340       0.000000
# value.Computers and Electronics               0.164732       0.000000
# value.Visual Color Discrimination             0.138677       0.000000
# value.Visualization                           0.132391       0.000000
# value.Technology Design                       0.129729       0.000000
# value.Foreign Language                        0.097921       0.000000
# value.Problem Sensitivity                     0.389449       0.000000
# value.Complex Problem Solving                 0.366589       0.000000
# value.Education and Training                  0.292071      -0.032776
# value.Hearing Sensitivity                     0.281612       0.000000
# value.Production and Processing               0.258097       0.000000
# value.Food Production                         0.253348       0.000000
# value.Design                                  0.247108       0.000000
# value.Time Management                         0.232075       0.000000
# value.Instructing                             0.229104       0.000000
# value.Information Ordering                    0.226909       0.000000
# value.Gross Body Coordination                 0.209479       0.000000
# value.Communications and Media                0.197584       0.000000
# value.Arm-Hand Steadiness                     0.195726      -0.007884
# value.Personnel and Human Resources           0.194237       0.000000
# value.Speech Clarity                          0.192078       0.000000
# value.Learning Strategies                     0.190938       0.000000
# value.Static Strength                         0.190498       0.000000
# ...                                                ...            ...
# value.Equipment Selection                     0.173811       0.000000
# value.History and Archeology                  0.172121       0.000000
# value.Management of Personnel Resources       0.168130       0.000000
# value.Mechanical                              0.162675       0.000000
# value.Operation Monitoring                    0.159681       0.000000
# value.Wrist-Finger Speed                      0.157329       0.000000
# value.Active Listening                        0.157278       0.000000
# value.Equipment Maintenance                   0.152911       0.000000
# value.Building and Construction               0.146760       0.000000
# value.Mathematical Reasoning                  0.146201       0.000000
# value.Troubleshooting                         0.144976       0.000000
# value.Written Expression                      0.144139       0.000000
# value.Auditory Attention                      0.137756       0.000000
# value.Multilimb Coordination                  0.132244       0.000000
# value.Finger Dexterity                        0.132029       0.000000
# value.Dynamic Flexibility                     0.131583       0.000000
# value.English Language                        0.131188       0.000000
# value.Medicine and Dentistry                  0.129380       0.000000
# value.Response Orientation                    0.126201       0.000000
# value.Therapy and Counseling                  0.118705       0.000000
# value.Far Vision                              0.115031       0.000000
# value.Speed of Limb Movement                  0.113104       0.000000
# value.Trunk Strength                          0.104924       0.000000
# value.Installation                            0.104663       0.000000
# value.Philosophy and Theology                 0.100534       0.000000
# value.Repairing                               0.093951       0.000000
# value.Science                                 0.088643       0.000000
# value.Sociology and Anthropology              0.080701       0.000000
# value.Perceptual Speed                        0.075287       0.000000
# value.Telecommunications                      0.061957       0.000000
#
#                                           pct_pos  occurance count  count  \
# main
# value.Memorization                       1.000000        18.133333     15
# value.Service Orientation                0.996825        23.333333     15
# value.Psychology                         1.000000        13.937500     16
# value.Fine Arts                          1.000000        12.944444     18
# value.Social Perceptiveness              1.000000         9.769231     13
# value.Customer and Personal Service      1.000000        22.916667     12
# value.Chemistry                          0.995385        26.500000     10
# value.Management of Material Resources   1.000000         4.900000     10
# value.Computers and Electronics          1.000000        24.800000     10
# value.Visual Color Discrimination        1.000000         6.400000     10
# value.Visualization                      1.000000         8.000000     13
# value.Technology Design                  1.000000        25.800000     10
# value.Foreign Language                   1.000000        20.307692     13
# value.Problem Sensitivity                1.000000         4.800000      5
# value.Complex Problem Solving            1.000000         7.600000      5
# value.Education and Training             0.995960        20.555556      9
# value.Hearing Sensitivity                1.000000         5.166667      6
# value.Production and Processing          1.000000         6.000000      6
# value.Food Production                    1.000000        10.400000      5
# value.Design                             1.000000        28.333333      6
# value.Time Management                    1.000000        10.555556      9
# value.Instructing                        1.000000        15.777778      9
# value.Information Ordering               1.000000        18.166667      6
# value.Gross Body Coordination            1.000000         4.833333      6
# value.Communications and Media           1.000000         4.200000      5
# value.Arm-Hand Steadiness                0.995833        15.750000      8
# value.Personnel and Human Resources      1.000000         9.200000      5
# value.Speech Clarity                     1.000000         5.000000      6
# value.Learning Strategies                1.000000         4.600000      5
# value.Static Strength                    1.000000         3.400000      5
# ...                                           ...              ...    ...
# value.Equipment Selection                1.000000         9.888889      9
# value.History and Archeology             1.000000         6.142857      7
# value.Management of Personnel Resources  1.000000        12.142857      7
# value.Mechanical                         1.000000         4.333333      6
# value.Operation Monitoring               1.000000         5.200000      5
# value.Wrist-Finger Speed                 1.000000         9.600000      5
# value.Active Listening                   1.000000         4.400000      5
# value.Equipment Maintenance              1.000000         4.000000      6
# value.Building and Construction          1.000000         5.625000      8
# value.Mathematical Reasoning             1.000000        12.000000      5
# value.Troubleshooting                    1.000000        17.333333      6
# value.Written Expression                 1.000000         5.000000      6
# value.Auditory Attention                 1.000000         8.600000      5
# value.Multilimb Coordination             1.000000        10.800000      5
# value.Finger Dexterity                   1.000000         8.000000      7
# value.Dynamic Flexibility                1.000000        10.600000      5
# value.English Language                   1.000000         4.833333      6
# value.Medicine and Dentistry             1.000000         9.666667      6
# value.Response Orientation               1.000000        10.000000      6
# value.Therapy and Counseling             1.000000         4.714286      7
# value.Far Vision                         1.000000         4.714286      7
# value.Speed of Limb Movement             1.000000         3.600000      5
# value.Trunk Strength                     1.000000         5.500000      6
# value.Installation                       1.000000        14.428571      7
# value.Philosophy and Theology            1.000000        10.000000      7
# value.Repairing                          1.000000        16.000000      7
# value.Science                            1.000000         9.000000      5
# value.Sociology and Anthropology         1.000000         6.333333      6
# value.Perceptual Speed                   1.000000         6.000000      5
# value.Telecommunications                 1.000000         4.166667      6
#
#                                         significance
# main
# value.Memorization                               ***
# value.Service Orientation                        ***
# value.Psychology                                 ***
# value.Fine Arts                                  ***
# value.Social Perceptiveness                       **
# value.Customer and Personal Service               **
# value.Chemistry                                   **
# value.Management of Material Resources            **
# value.Computers and Electronics                   **
# value.Visual Color Discrimination                 **
# value.Visualization                               **
# value.Technology Design                           **
# value.Foreign Language                            **
# value.Problem Sensitivity                          *
# value.Complex Problem Solving                      *
# value.Education and Training                       *
# value.Hearing Sensitivity                          *
# value.Production and Processing                    *
# value.Food Production                              *
# value.Design                                       *
# value.Time Management                              *
# value.Instructing                                  *
# value.Information Ordering                         *
# value.Gross Body Coordination                      *
# value.Communications and Media                     *
# value.Arm-Hand Steadiness                          *
# value.Personnel and Human Resources                *
# value.Speech Clarity                               *
# value.Learning Strategies                          *
# value.Static Strength                              *
# ...                                              ...
# value.Equipment Selection                          *
# value.History and Archeology                       *
# value.Management of Personnel Resources            *
# value.Mechanical                                   *
# value.Operation Monitoring                         *
# value.Wrist-Finger Speed                           *
# value.Active Listening                             *
# value.Equipment Maintenance                        *
# value.Building and Construction                    *
# value.Mathematical Reasoning                       *
# value.Troubleshooting                              *
# value.Written Expression                           *
# value.Auditory Attention                           *
# value.Multilimb Coordination                       *
# value.Finger Dexterity                             *
# value.Dynamic Flexibility                          *
# value.English Language                             *
# value.Medicine and Dentistry                       *
# value.Response Orientation                         *
# value.Therapy and Counseling                       *
# value.Far Vision                                   *
# value.Speed of Limb Movement                       *
# value.Trunk Strength                               *
# value.Installation                                 *
# value.Philosophy and Theology                      *
# value.Repairing                                    *
# value.Science                                      *
# value.Sociology and Anthropology                   *
# value.Perceptual Speed                             *
# value.Telecommunications                           *
#
# [66 rows x 6 columns]

# %%
sig_pairs.xs('high value.Problem Sensitivity',level=1).sort_values(['significance','pos_influence'],ascending=False)
# Out:
#                                          pos_influence  neg_influence  \
# main
# value.Computers and Electronics               0.249367       0.000000
# value.Technology Design                       0.123466       0.000000
# value.Memorization                            0.267263       0.000000
# value.Service Orientation                     0.248153       0.000000
# value.Explosive Strength                      0.242702       0.000000
# value.Visualization                           0.230645       0.000000
# value.Equipment Selection                     0.218067       0.000000
# value.Instructing                             0.194762       0.000000
# value.Arm-Hand Steadiness                     0.190443       0.000000
# value.Psychology                              0.189002      -0.001419
# value.Auditory Attention                      0.178114       0.000000
# value.Information Ordering                    0.172236       0.000000
# value.Fine Arts                               0.171599       0.000000
# value.Systems Evaluation                      0.169049       0.000000
# value.Philosophy and Theology                 0.134839       0.000000
# value.Foreign Language                        0.120235       0.000000
# value.Therapy and Counseling                  0.081241      -0.003730
# value.Written Comprehension                   0.271725       0.000000
# value.Multilimb Coordination                  0.265783       0.000000
# value.Active Learning                         0.244836       0.000000
# value.History and Archeology                  0.237931       0.000000
# value.Speaking                                0.237919       0.000000
# value.Visual Color Discrimination             0.237300       0.000000
# value.Time Management                         0.233005       0.000000
# value.Critical Thinking                       0.231548       0.000000
# value.Administration and Management           0.226901       0.000000
# value.Design                                  0.225262       0.000000
# value.Complex Problem Solving                 0.220776       0.000000
# value.Finger Dexterity                        0.219738       0.000000
# value.Biology                                 0.215683       0.000000
# ...                                                ...            ...
# value.Public Safety and Security              0.184998       0.000000
# value.Repairing                               0.176122       0.000000
# value.Persuasion                              0.175561       0.000000
# value.Social Perceptiveness                   0.167807       0.000000
# value.Oral Comprehension                      0.164266       0.000000
# value.Mechanical                              0.160039       0.000000
# value.Stamina                                 0.159521       0.000000
# value.Troubleshooting                         0.156320       0.000000
# value.Mathematical Reasoning                  0.152575       0.000000
# value.Medicine and Dentistry                  0.140474       0.000000
# value.Originality                             0.140407       0.000000
# value.Geography                               0.138472       0.000000
# value.Food Production                         0.131440       0.000000
# value.Speech Recognition                      0.124612       0.000000
# value.Engineering and Technology              0.116831      -0.004657
# value.Quality Control Analysis                0.113203       0.000000
# value.Installation                            0.111940       0.000000
# value.English Language                        0.111745       0.000000
# value.Judgment and Decision Making            0.110493       0.000000
# value.Management of Financial Resources       0.109840       0.000000
# value.Systems Analysis                        0.107564       0.000000
# value.Active Listening                        0.098250       0.000000
# value.Sociology and Anthropology              0.096629       0.000000
# value.Extent Flexibility                      0.096073       0.000000
# value.Dynamic Flexibility                     0.094710       0.000000
# value.Trunk Strength                          0.091458       0.000000
# value.Telecommunications                      0.086873       0.000000
# value.Flexibility of Closure                  0.083900       0.000000
# value.Static Strength                         0.079824       0.000000
# value.Communications and Media                0.066131       0.000000
#
#                                           pct_pos  occurance count  count  \
# main
# value.Computers and Electronics          1.000000        23.866667     15
# value.Technology Design                  1.000000        27.400000     15
# value.Memorization                       1.000000        35.071429     14
# value.Service Orientation                1.000000        26.428571     14
# value.Explosive Strength                 1.000000        14.166667     12
# value.Visualization                      1.000000         7.700000     10
# value.Equipment Selection                1.000000        17.600000     10
# value.Instructing                        1.000000        10.142857     14
# value.Arm-Hand Steadiness                1.000000        12.916667     12
# value.Psychology                         0.997222        18.166667     12
# value.Auditory Attention                 1.000000        13.300000     10
# value.Information Ordering               1.000000         5.636364     11
# value.Fine Arts                          1.000000        13.000000     14
# value.Systems Evaluation                 1.000000        18.166667     12
# value.Philosophy and Theology            1.000000         9.461538     13
# value.Foreign Language                   1.000000        13.833333     12
# value.Therapy and Counseling             0.996289        19.090909     11
# value.Written Comprehension              1.000000         6.833333      6
# value.Multilimb Coordination             1.000000         7.000000      8
# value.Active Learning                    1.000000         7.833333      6
# value.History and Archeology             1.000000         7.250000      8
# value.Speaking                           1.000000         5.800000      5
# value.Visual Color Discrimination        1.000000        10.000000      9
# value.Time Management                    1.000000         7.600000      5
# value.Critical Thinking                  1.000000         6.400000      5
# value.Administration and Management      1.000000         9.666667      6
# value.Design                             1.000000        25.750000      8
# value.Complex Problem Solving            1.000000        13.250000      8
# value.Finger Dexterity                   1.000000        10.000000      7
# value.Biology                            1.000000        11.166667      6
# ...                                           ...              ...    ...
# value.Public Safety and Security         1.000000         6.777778      9
# value.Repairing                          1.000000        11.400000      5
# value.Persuasion                         1.000000        18.875000      8
# value.Social Perceptiveness              1.000000         6.500000      6
# value.Oral Comprehension                 1.000000         8.750000      8
# value.Mechanical                         1.000000        16.111111      9
# value.Stamina                            1.000000         9.285714      7
# value.Troubleshooting                    1.000000        25.833333      6
# value.Mathematical Reasoning             1.000000         5.200000      5
# value.Medicine and Dentistry             1.000000        10.000000      8
# value.Originality                        1.000000         4.000000      5
# value.Geography                          1.000000         6.000000      5
# value.Food Production                    1.000000         8.111111      9
# value.Speech Recognition                 1.000000         5.714286      7
# value.Engineering and Technology         0.994580        24.555556      9
# value.Quality Control Analysis           1.000000         9.500000      6
# value.Installation                       1.000000        18.875000      8
# value.English Language                   1.000000         6.000000      5
# value.Judgment and Decision Making       1.000000         4.500000      6
# value.Management of Financial Resources  1.000000         6.000000      5
# value.Systems Analysis                   1.000000         8.285714      7
# value.Active Listening                   1.000000         8.250000      8
# value.Sociology and Anthropology         1.000000        17.428571      7
# value.Extent Flexibility                 1.000000         4.125000      8
# value.Dynamic Flexibility                1.000000         9.375000      8
# value.Trunk Strength                     1.000000         4.000000      5
# value.Telecommunications                 1.000000         6.400000      5
# value.Flexibility of Closure             1.000000         3.500000      6
# value.Static Strength                    1.000000         5.400000      5
# value.Communications and Media           1.000000         4.200000      5
#
#                                         significance
# main
# value.Computers and Electronics                  ***
# value.Technology Design                          ***
# value.Memorization                                **
# value.Service Orientation                         **
# value.Explosive Strength                          **
# value.Visualization                               **
# value.Equipment Selection                         **
# value.Instructing                                 **
# value.Arm-Hand Steadiness                         **
# value.Psychology                                  **
# value.Auditory Attention                          **
# value.Information Ordering                        **
# value.Fine Arts                                   **
# value.Systems Evaluation                          **
# value.Philosophy and Theology                     **
# value.Foreign Language                            **
# value.Therapy and Counseling                      **
# value.Written Comprehension                        *
# value.Multilimb Coordination                       *
# value.Active Learning                              *
# value.History and Archeology                       *
# value.Speaking                                     *
# value.Visual Color Discrimination                  *
# value.Time Management                              *
# value.Critical Thinking                            *
# value.Administration and Management                *
# value.Design                                       *
# value.Complex Problem Solving                      *
# value.Finger Dexterity                             *
# value.Biology                                      *
# ...                                              ...
# value.Public Safety and Security                   *
# value.Repairing                                    *
# value.Persuasion                                   *
# value.Social Perceptiveness                        *
# value.Oral Comprehension                           *
# value.Mechanical                                   *
# value.Stamina                                      *
# value.Troubleshooting                              *
# value.Mathematical Reasoning                       *
# value.Medicine and Dentistry                       *
# value.Originality                                  *
# value.Geography                                    *
# value.Food Production                              *
# value.Speech Recognition                           *
# value.Engineering and Technology                   *
# value.Quality Control Analysis                     *
# value.Installation                                 *
# value.English Language                             *
# value.Judgment and Decision Making                 *
# value.Management of Financial Resources            *
# value.Systems Analysis                             *
# value.Active Listening                             *
# value.Sociology and Anthropology                   *
# value.Extent Flexibility                           *
# value.Dynamic Flexibility                          *
# value.Trunk Strength                               *
# value.Telecommunications                           *
# value.Flexibility of Closure                       *
# value.Static Strength                              *
# value.Communications and Media                     *
#
# [69 rows x 6 columns]

# %%
sig_pairs.xs('high value.Active Listening',level=1).sort_values(['significance','pos_influence'],ascending=False)
# Out:
#                                          pos_influence  neg_influence  \
# main
# value.Education and Training                  0.228990       0.000000
# value.Memorization                            0.283647      -0.021542
# value.Mechanical                              0.247791       0.000000
# value.Service Orientation                     0.245321       0.000000
# value.Visualization                           0.236069       0.000000
# value.Explosive Strength                      0.230288       0.000000
# value.Design                                  0.220413       0.000000
# value.Chemistry                               0.206293       0.000000
# value.Technology Design                       0.180733       0.000000
# value.Auditory Attention                      0.180149       0.000000
# value.Biology                                 0.160479       0.000000
# value.Number Facility                         0.322853       0.000000
# value.Sales and Marketing                     0.299520       0.000000
# value.Quality Control Analysis                0.262333       0.000000
# value.Management of Personnel Resources       0.260758       0.000000
# value.Systems Evaluation                      0.245104       0.000000
# value.Hearing Sensitivity                     0.243316       0.000000
# value.Complex Problem Solving                 0.228731       0.000000
# value.Information Ordering                    0.220364       0.000000
# value.Instructing                             0.214115       0.000000
# value.Mathematics Knowledge                   0.213138       0.000000
# value.Customer and Personal Service           0.209782       0.000000
# value.Therapy and Counseling                  0.187558       0.000000
# value.Equipment Selection                     0.183772       0.000000
# value.Personnel and Human Resources           0.182493       0.000000
# value.Depth Perception                        0.179429       0.000000
# value.Troubleshooting                         0.178371       0.000000
# value.Extent Flexibility                      0.171712       0.000000
# value.History and Archeology                  0.167065       0.000000
# value.Reaction Time                           0.161073       0.000000
# value.Visual Color Discrimination             0.159157       0.000000
# value.Engineering and Technology              0.158231      -0.000635
# value.Multilimb Coordination                  0.156785       0.000000
# value.Computers and Electronics               0.151003       0.000000
# value.Medicine and Dentistry                  0.146612       0.000000
# value.Arm-Hand Steadiness                     0.146333       0.000000
# value.Physics                                 0.143307       0.000000
# value.Production and Processing               0.142931       0.000000
# value.Fine Arts                               0.138253       0.000000
# value.Speech Recognition                      0.137826       0.000000
# value.Glare Sensitivity                       0.132928       0.000000
# value.Speed of Limb Movement                  0.131821       0.000000
# value.Trunk Strength                          0.130843       0.000000
# value.Persuasion                              0.118704       0.000000
# value.Administration and Management           0.115044       0.000000
# value.Monitoring                              0.100918       0.000000
# value.Far Vision                              0.092144       0.000000
# value.Management of Material Resources        0.083190       0.000000
# value.Food Production                         0.081112       0.000000
# value.Philosophy and Theology                 0.073116       0.000000
# value.Control Precision                       0.071887       0.000000
# value.Gross Body Coordination                 0.068377       0.000000
# value.Sociology and Anthropology              0.061687       0.000000
#
#                                           pct_pos  occurance count  count  \
# main
# value.Education and Training             1.000000        11.400000     15
# value.Memorization                       0.997658        27.214286     14
# value.Mechanical                         1.000000        15.100000     10
# value.Service Orientation                1.000000        14.600000     10
# value.Visualization                      1.000000        24.700000     10
# value.Explosive Strength                 1.000000        14.272727     11
# value.Design                             1.000000        20.500000     12
# value.Chemistry                          1.000000        19.769231     13
# value.Technology Design                  1.000000        22.583333     12
# value.Auditory Attention                 1.000000        12.916667     12
# value.Biology                            1.000000        16.400000     10
# value.Number Facility                    1.000000         6.800000      5
# value.Sales and Marketing                1.000000         6.166667      6
# value.Quality Control Analysis           1.000000        12.833333      6
# value.Management of Personnel Resources  1.000000         7.000000      7
# value.Systems Evaluation                 1.000000        17.428571      7
# value.Hearing Sensitivity                1.000000         9.500000      6
# value.Complex Problem Solving            1.000000         6.333333      6
# value.Information Ordering               1.000000         4.200000      5
# value.Instructing                        1.000000        11.400000      5
# value.Mathematics Knowledge              1.000000         5.600000      5
# value.Customer and Personal Service      1.000000         9.333333      9
# value.Therapy and Counseling             1.000000         7.000000      6
# value.Equipment Selection                1.000000        11.000000      7
# value.Personnel and Human Resources      1.000000         4.800000      5
# value.Depth Perception                   1.000000        18.857143      7
# value.Troubleshooting                    1.000000        25.500000      6
# value.Extent Flexibility                 1.000000         6.333333      6
# value.History and Archeology             1.000000         5.800000      5
# value.Reaction Time                      1.000000         7.666667      6
# value.Visual Color Discrimination        1.000000         5.000000      8
# value.Engineering and Technology         0.994318        16.750000      8
# value.Multilimb Coordination             1.000000        10.125000      8
# value.Computers and Electronics          1.000000        17.000000      7
# value.Medicine and Dentistry             1.000000         7.555556      9
# value.Arm-Hand Steadiness                1.000000         9.375000      8
# value.Physics                            1.000000         3.400000      5
# value.Production and Processing          1.000000         4.750000      8
# value.Fine Arts                          1.000000         9.285714      7
# value.Speech Recognition                 1.000000         6.200000      5
# value.Glare Sensitivity                  1.000000         3.600000      5
# value.Speed of Limb Movement             1.000000         4.333333      6
# value.Trunk Strength                     1.000000        10.444444      9
# value.Persuasion                         1.000000         9.000000      6
# value.Administration and Management      1.000000         4.833333      6
# value.Monitoring                         1.000000         3.500000      6
# value.Far Vision                         1.000000         5.000000      6
# value.Management of Material Resources   1.000000         6.666667      9
# value.Food Production                    1.000000         9.000000      9
# value.Philosophy and Theology            1.000000        10.333333      6
# value.Control Precision                  1.000000         4.500000      6
# value.Gross Body Coordination            1.000000         3.600000      5
# value.Sociology and Anthropology         1.000000         6.375000      8
#
#                                         significance
# main
# value.Education and Training                     ***
# value.Memorization                                **
# value.Mechanical                                  **
# value.Service Orientation                         **
# value.Visualization                               **
# value.Explosive Strength                          **
# value.Design                                      **
# value.Chemistry                                   **
# value.Technology Design                           **
# value.Auditory Attention                          **
# value.Biology                                     **
# value.Number Facility                              *
# value.Sales and Marketing                          *
# value.Quality Control Analysis                     *
# value.Management of Personnel Resources            *
# value.Systems Evaluation                           *
# value.Hearing Sensitivity                          *
# value.Complex Problem Solving                      *
# value.Information Ordering                         *
# value.Instructing                                  *
# value.Mathematics Knowledge                        *
# value.Customer and Personal Service                *
# value.Therapy and Counseling                       *
# value.Equipment Selection                          *
# value.Personnel and Human Resources                *
# value.Depth Perception                             *
# value.Troubleshooting                              *
# value.Extent Flexibility                           *
# value.History and Archeology                       *
# value.Reaction Time                                *
# value.Visual Color Discrimination                  *
# value.Engineering and Technology                   *
# value.Multilimb Coordination                       *
# value.Computers and Electronics                    *
# value.Medicine and Dentistry                       *
# value.Arm-Hand Steadiness                          *
# value.Physics                                      *
# value.Production and Processing                    *
# value.Fine Arts                                    *
# value.Speech Recognition                           *
# value.Glare Sensitivity                            *
# value.Speed of Limb Movement                       *
# value.Trunk Strength                               *
# value.Persuasion                                   *
# value.Administration and Management                *
# value.Monitoring                                   *
# value.Far Vision                                   *
# value.Management of Material Resources             *
# value.Food Production                              *
# value.Philosophy and Theology                      *
# value.Control Precision                            *
# value.Gross Body Coordination                      *
# value.Sociology and Anthropology                   *

# %% [markdown]
# What makes knowledges more useful

# %%
knowledges = np.unique(pd.read_excel('../../../raw_data/ONET_data/knowledge.xlsx')['Element Name'])
knowledges = 'value.' + pd.Series(knowledges).astype(str)
knowledges = knowledges.append(pd.Series(['value.Mathematics Knowledge']))

# %%
#filter out non knowledges, left direction pairings
knowledge_pairs = sig_pairs.loc[np.isin(sig_pairs.index.get_level_values(0),knowledges)]
right_dirs = [i for i,item in 
              enumerate(knowledge_pairs.index.get_level_values(1)) 
              if "high" in item]
knowledge_pairs = knowledge_pairs.iloc[right_dirs]
knowledge_pairs = knowledge_pairs.loc[
    np.logical_not(np.isin(knowledge_pairs.index.get_level_values(1),
                           ('high ' + pd.Series(foundational).astype(str))))
]

# %%
#sort by pos_influence. grab the top 3 for each knowledge-signficance combo
knowledge_pairs = knowledge_pairs.sort_values('pos_influence',ascending=False)
knowledge_pairs.groupby(
    [knowledge_pairs.index.get_level_values(0),'significance']
).head(3).sort_values(['main','significance'],
                      ascending = False).to_csv('../../../tables/model_output/knowledge_pairs.csv')

# %% [markdown]
# If I have a SKA, what else should I get

# %%
main_skas = pd.read_csv("../../../tables/processed_dem_tables/major_group_main_SKAs.csv")
main_skas['SKA'] = ['high '+ s for s in main_skas['SKA']]
helpful_pairs = sig_pairs.loc[np.isin(sig_pairs.index.get_level_values(1),main_skas['SKA'])]
helpful_pairs = helpful_pairs.loc[
    np.logical_not(np.isin(helpful_pairs.index.get_level_values(0),foundational))
]

temp = pd.DataFrame()
for occ_group in np.unique(main_skas['dig1']):
    base_skas = main_skas.loc[main_skas['dig1']==occ_group]["SKA"]
    occ_pairs = helpful_pairs.loc[
        np.isin(
            helpful_pairs.index.get_level_values(1),base_skas
        )].copy()
    occ_pairs['occ_group'] = occ_group
    occ_pairs.reset_index(inplace=True)
    occ_pairs.set_index(['main','conditional','occ_group'],inplace=True)

    temp = temp.append(occ_pairs)

helpful_pairs = temp.loc[temp['significance']!='not sig'].sort_values('pos_influence',ascending=False).copy()
helpful_pairs.groupby(
    [helpful_pairs.index.get_level_values(2),'significance']
).head(4).sort_values(['occ_group','significance'],
                      ascending=False).to_csv('../../../tables/model_output/occ_pairs.csv')

# %%
# again we need shit to be consitent so we run 10 times and take averages
for i in range(10):
    rf = RandomForestClassifier(**init_params('cat')).fit(x,y['increase'])
    conditionals = list(range(120))+list(range(-119,0))+['blank']
    all_combos = init_influence_list(range(120),conditionals,True)
    current_infl = feature_name_index(get_influences(all_combos,rf),x.columns).fillna(0)

#     pairs = current_infl[
#     np.logical_not(
#         np.in1d(current_infl.index.get_level_values(1), 'blank')
#     )].copy()
    
#     current_sig_pairs = pairs.loc[pairs['pct_pos']>0.95].copy()
    current_sig_pairs = current_infl
    current_sig_pairs['count']=1
    if i==0:
        sig_pairs = current_sig_pairs
    else:
        common_idx = sig_pairs.index.intersection(current_sig_pairs.index) #grab the pair we have seen
        for_update = sig_pairs.loc[common_idx,sig_pairs.columns != 'count'].copy()#make lists of old and new info
        update_with = current_sig_pairs.loc[common_idx,sig_pairs.columns != 'count'].copy()
        new_pairs = current_sig_pairs.loc[~current_sig_pairs.index.isin(common_idx)].copy()#new rows
        counts = sig_pairs.loc[common_idx,'count'].copy()
        updated  = (for_update.mul(counts,axis=0).add(update_with,axis=0)).div(counts+1,axis=0)
        
        sig_pairs.loc[common_idx,sig_pairs.columns != 'count'] = updated.copy()
        sig_pairs.loc[common_idx,'count'] = sig_pairs.loc[common_idx,'count']+1
        sig_pairs = pd.concat([sig_pairs,new_pairs])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sig_traits = ['value.Active Listening','value.Customer and Personal Service','value.Fine Arts',
              'value.Fluency of Ideas','value.Installation','value.Instructing',
              'value.Memorization','value.Number Facility','value.Originality',
              'value.Persuasion','value.Philosophy and Theology','value.Service Orientation',
              'value.Systems Analysis','value.Systems Evaluation','value.Technology Design',
              'value.Visualization']

# %%
sig_pairs.loc[np.isin(sig_pairs.index.get_level_values(0),sig_traits)].xs('blank',level=1)
# Out:
#                                      pos_influence  neg_influence   pct_pos  \
# main
# value.Active Listening                    0.254047      -0.154189  0.874591
# value.Persuasion                          0.376350      -0.167471  0.975152
# value.Instructing                         0.324980      -0.131678  0.968777
# value.Service Orientation                 0.304465      -0.144257  0.966862
# value.Technology Design                   0.184293      -0.192784  0.957534
# value.Installation                        0.150923      -0.159320  0.884502
# value.Systems Analysis                    0.340178      -0.133671  0.928313
# value.Systems Evaluation                  0.341443      -0.149077  0.959226
# value.Fluency of Ideas                    0.393847      -0.126934  0.962507
# value.Originality                         0.344119      -0.117609  0.942734
# value.Number Facility                     0.319611      -0.145974  0.921660
# value.Memorization                        0.306133      -0.112401  0.992009
# value.Visualization                       0.223733      -0.241287  0.933236
# value.Customer and Personal Service       0.255333      -0.199726  0.901891
# value.Fine Arts                           0.149052      -0.139961  0.925728
# value.Philosophy and Theology             0.191913      -0.141259  0.881618
#
#                                      occurance count  count
# main
# value.Active Listening                         311.5     10
# value.Persuasion                              1623.0     10
# value.Instructing                             1093.3     10
# value.Service Orientation                     1562.6     10
# value.Technology Design                       1311.1     10
# value.Installation                             356.8     10
# value.Systems Analysis                         874.1     10
# value.Systems Evaluation                      1098.3     10
# value.Fluency of Ideas                        1618.9     10
# value.Originality                             1043.2     10
# value.Number Facility                          692.6     10
# value.Memorization                            1614.9     10
# value.Visualization                            907.1     10
# value.Customer and Personal Service           1179.5     10
# value.Fine Arts                                416.1     10
# value.Philosophy and Theology                  476.5     10

# %%
sig_pairs.loc[sig_pairs.index.get_level_values(0)=='value.Deductive Reasoning'].xs('blank',level=1)
# Out:
#                            pos_influence  neg_influence   pct_pos  \
# main
# value.Deductive Reasoning       0.248708      -0.180842  0.909868
#
#                            occurance count  count
# main
# value.Deductive Reasoning            344.3     10
