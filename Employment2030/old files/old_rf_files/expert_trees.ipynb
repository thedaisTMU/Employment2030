# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

# %%
#reading the data
file = "C:/Users/USERID/Documents/GitHub/Employment2030/Employment2030/tables/scores_answers.csv"

data = pd.read_csv(file,index_col=['noc','workshop.number'])
data.sort_index(inplace=True)
data.loc[data.share == 'remain constant','share'] = 'constant'
data.dropna(inplace=True)

#splitting up x and y
x = data.drop(['absolute','share','Unnamed: 0','noc_code'],axis=1) #making x data frame
x['work_num'] = x.index.get_level_values(1) #making workshop number a variable as well as an index
x = np.round(x).astype(int)#round x to make discrete

y_abs = data['absolute']
y_share = data['share']
y_share_bin = y_share.where(y_share=='increase','not_increase')

# %%
#aggragate y to test against

y_share_agg = pd.DataFrame(data['share']).pivot_table(index = ['noc','workshop.number'], columns = 'share', aggfunc = len).fillna(0)
y_share_agg['sum'] = y_share_agg.sum(axis = 1)
y_share_agg['not_increase'] = y_share_agg['decrease'] + y_share_agg['constant']
y_share_agg.loc[:,y_share_agg.columns!='sum'] = y_share_agg.loc[:,y_share_agg.columns!='sum'].divide(y_share_agg['sum'],axis=0)
y_share_agg['y'] = y_share_agg[['constant','decrease','increase']].idxmax(axis=1)
y_share_agg['binned_y'] = y_share_agg[['increase','not_increase']].idxmax(axis=1)

# %%
#not binned
rf = RandomForestClassifier(class_weight="balanced",n_estimators=1000,n_jobs=-1)

predictions = np.zeros((2419,3))

kf = KFold(n_splits=10,shuffle=False)
for train_index, test_index in kf.split(x):
    x_train, x_test = x.iloc[train_index], x.iloc[test_index]
    y_train, y_test = y_share.iloc[train_index], y_share.iloc[test_index]
    rf.fit(x_train,y_train)
    predictions[test_index] = rf.predict_proba(x_test)

# %%
agg_predictions = pd.DataFrame(predictions,index=x.index).mean(level=[0,1])

# %%
accuracy = pd.DataFrame({'constant':abs(agg_predictions.iloc[:,0]-y_share_agg['constant']),
              'decrease':abs(agg_predictions.iloc[:,1]-y_share_agg['decrease']),
              'increase':abs(agg_predictions.iloc[:,2]-y_share_agg['increase'])},
            index = y_share_agg.index)

# %%
accuracy.mean()
# Out:
# constant    0.118208
# decrease    0.179168
# increase    0.179239
# dtype: float64

# %%
plt.plot(y_share_agg['increase'],accuracy['increase'],'bo')

# %%
pd.DataFrame({"truth":y_share_agg['y'], "guess":accuracy.idxmax(axis=1)})
# Out:
#                                                                        truth  \
# noc                                                workshop.number
# Accommodation service managers                     4                constant
# Accounting technicians and bookkeepers             4                decrease
# Air pilots, flight engineers and flying instruc... 3                constant
# Air transport ramp attendants                      3                decrease
# Airline ticket and service agents                  3                decrease
# Carpenters                                         3                increase
# Central control and process operators, petroleu... 1                decrease
# Chefs                                              4                increase
# Computer network technicians                       1                increase
#                                                    2                increase
#                                                    3                increase
#                                                    4                increase
#                                                    5                increase
#                                                    6                increase
# Cooks                                              5                increase
# Correctional service officers                      3                constant
# Court clerks                                       1                decrease
#                                                    2                decrease
#                                                    3                decrease
#                                                    4                decrease
#                                                    5                constant
#                                                    6                decrease
# Delivery and courier service drivers               5                constant
# Electrical mechanics                               1                increase
#                                                    2                increase
#                                                    3                increase
#                                                    4                increase
#                                                    5                increase
#                                                    6                increase
# Financial managers                                 1                decrease
# ...                                                                      ...
# Plastics processing machine operators              2                decrease
#                                                    3                decrease
#                                                    4                decrease
#                                                    5                decrease
#                                                    6                decrease
# Real estate agents and salespersons                2                constant
# Registered nurses and registered psychiatric nu... 6                increase
# Restaurant and food service managers               2                increase
# Senior managers - financial, communications and... 1                increase
#                                                    2                constant
#                                                    3                constant
#                                                    4                increase
#                                                    5                constant
#                                                    6                constant
# Shippers and receivers                             5                decrease
# Steamfitters, pipefitters and sprinkler system ... 6                constant
# Store shelf stockers, clerks and order fillers     5                decrease
# Supervisors, petroleum, gas and chemical proces... 1                constant
#                                                    2                constant
#                                                    3                increase
#                                                    4                constant
#                                                    5                decrease
#                                                    6                increase
# Technical sales specialists - wholesale trade      2                increase
# Underground production and development miners      1                decrease
#                                                    2                decrease
#                                                    3                decrease
#                                                    4                decrease
#                                                    5                decrease
#                                                    6                decrease
#
#                                                                        guess
# noc                                                workshop.number
# Accommodation service managers                     4                constant
# Accounting technicians and bookkeepers             4                increase
# Air pilots, flight engineers and flying instruc... 3                constant
# Air transport ramp attendants                      3                decrease
# Airline ticket and service agents                  3                decrease
# Carpenters                                         3                increase
# Central control and process operators, petroleu... 1                increase
# Chefs                                              4                increase
# Computer network technicians                       1                increase
#                                                    2                constant
#                                                    3                increase
#                                                    4                decrease
#                                                    5                decrease
#                                                    6                increase
# Cooks                                              5                increase
# Correctional service officers                      3                increase
# Court clerks                                       1                decrease
#                                                    2                increase
#                                                    3                decrease
#                                                    4                increase
#                                                    5                increase
#                                                    6                constant
# Delivery and courier service drivers               5                decrease
# Electrical mechanics                               1                decrease
#                                                    2                constant
#                                                    3                constant
#                                                    4                decrease
#                                                    5                decrease
#                                                    6                decrease
# Financial managers                                 1                decrease
# ...                                                                      ...
# Plastics processing machine operators              2                decrease
#                                                    3                increase
#                                                    4                decrease
#                                                    5                constant
#                                                    6                decrease
# Real estate agents and salespersons                2                increase
# Registered nurses and registered psychiatric nu... 6                increase
# Restaurant and food service managers               2                increase
# Senior managers - financial, communications and... 1                increase
#                                                    2                increase
#                                                    3                increase
#                                                    4                decrease
#                                                    5                increase
#                                                    6                increase
# Shippers and receivers                             5                decrease
# Steamfitters, pipefitters and sprinkler system ... 6                constant
# Store shelf stockers, clerks and order fillers     5                decrease
# Supervisors, petroleum, gas and chemical proces... 1                constant
#                                                    2                decrease
#                                                    3                increase
#                                                    4                increase
#                                                    5                constant
#                                                    6                increase
# Technical sales specialists - wholesale trade      2                increase
# Underground production and development miners      1                decrease
#                                                    2                constant
#                                                    3                decrease
#                                                    4                increase
#                                                    5                decrease
#                                                    6                decrease
#
# [120 rows x 2 columns]

# %%
#binned
rf = RandomForestClassifier(class_weight="balanced",n_estimators=1000,n_jobs=-1)

predictions_bin = np.zeros((2419,2))

kf = KFold(n_splits=10,shuffle=False)
for train_index, test_index in kf.split(x):
    x_train, x_test = x.iloc[train_index], x.iloc[test_index]
    y_train, y_test = y_share_bin.iloc[train_index], y_share_bin.iloc[test_index]
    rf.fit(x_train,y_train)
    predictions_bin[test_index] = rf.predict_proba(x_test)

# %%
agg_predictions_bin = pd.DataFrame(predictions_bin,index=x.index).mean(level=[0,1])

# %%
accuracy_bin = pd.DataFrame({'increase':abs(agg_predictions_bin.iloc[:,0]-y_share_agg['increase']),
              'not_increase':abs(agg_predictions_bin.iloc[:,1]-y_share_agg['not_increase'])},
               index = y_share_agg.index)

# %%
accuracy_bin.mean()
# Out:
# increase        0.239921
# not_increase    0.239921
# dtype: float64

# %%
pd.DataFrame({"truth":y_share_agg['binned_y'], "guess":accuracy_bin.idxmax(axis=1)})
# Out:
#                                                                            truth  \
# noc                                                workshop.number
# Accommodation service managers                     4                not_increase
# Accounting technicians and bookkeepers             4                not_increase
# Air pilots, flight engineers and flying instruc... 3                not_increase
# Air transport ramp attendants                      3                not_increase
# Airline ticket and service agents                  3                not_increase
# Carpenters                                         3                not_increase
# Central control and process operators, petroleu... 1                not_increase
# Chefs                                              4                    increase
# Computer network technicians                       1                    increase
#                                                    2                    increase
#                                                    3                    increase
#                                                    4                    increase
#                                                    5                    increase
#                                                    6                    increase
# Cooks                                              5                    increase
# Correctional service officers                      3                not_increase
# Court clerks                                       1                not_increase
#                                                    2                not_increase
#                                                    3                not_increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                not_increase
# Delivery and courier service drivers               5                not_increase
# Electrical mechanics                               1                not_increase
#                                                    2                    increase
#                                                    3                    increase
#                                                    4                    increase
#                                                    5                    increase
#                                                    6                    increase
# Financial managers                                 1                not_increase
# ...                                                                          ...
# Plastics processing machine operators              2                not_increase
#                                                    3                not_increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                not_increase
# Real estate agents and salespersons                2                not_increase
# Registered nurses and registered psychiatric nu... 6                    increase
# Restaurant and food service managers               2                    increase
# Senior managers - financial, communications and... 1                not_increase
#                                                    2                not_increase
#                                                    3                not_increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                not_increase
# Shippers and receivers                             5                not_increase
# Steamfitters, pipefitters and sprinkler system ... 6                not_increase
# Store shelf stockers, clerks and order fillers     5                not_increase
# Supervisors, petroleum, gas and chemical proces... 1                not_increase
#                                                    2                not_increase
#                                                    3                    increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                    increase
# Technical sales specialists - wholesale trade      2                    increase
# Underground production and development miners      1                not_increase
#                                                    2                not_increase
#                                                    3                not_increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                not_increase
#
#                                                                            guess
# noc                                                workshop.number
# Accommodation service managers                     4                not_increase
# Accounting technicians and bookkeepers             4                not_increase
# Air pilots, flight engineers and flying instruc... 3                    increase
# Air transport ramp attendants                      3                    increase
# Airline ticket and service agents                  3                not_increase
# Carpenters                                         3                not_increase
# Central control and process operators, petroleu... 1                    increase
# Chefs                                              4                    increase
# Computer network technicians                       1                    increase
#                                                    2                not_increase
#                                                    3                    increase
#                                                    4                    increase
#                                                    5                not_increase
#                                                    6                not_increase
# Cooks                                              5                    increase
# Correctional service officers                      3                    increase
# Court clerks                                       1                not_increase
#                                                    2                not_increase
#                                                    3                not_increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                not_increase
# Delivery and courier service drivers               5                not_increase
# Electrical mechanics                               1                    increase
#                                                    2                not_increase
#                                                    3                not_increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                not_increase
# Financial managers                                 1                    increase
# ...                                                                          ...
# Plastics processing machine operators              2                not_increase
#                                                    3                not_increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                not_increase
# Real estate agents and salespersons                2                    increase
# Registered nurses and registered psychiatric nu... 6                not_increase
# Restaurant and food service managers               2                not_increase
# Senior managers - financial, communications and... 1                    increase
#                                                    2                    increase
#                                                    3                    increase
#                                                    4                    increase
#                                                    5                    increase
#                                                    6                    increase
# Shippers and receivers                             5                not_increase
# Steamfitters, pipefitters and sprinkler system ... 6                    increase
# Store shelf stockers, clerks and order fillers     5                    increase
# Supervisors, petroleum, gas and chemical proces... 1                    increase
#                                                    2                    increase
#                                                    3                    increase
#                                                    4                    increase
#                                                    5                    increase
#                                                    6                    increase
# Technical sales specialists - wholesale trade      2                not_increase
# Underground production and development miners      1                not_increase
#                                                    2                    increase
#                                                    3                not_increase
#                                                    4                not_increase
#                                                    5                not_increase
#                                                    6                    increase
#
# [120 rows x 2 columns]
