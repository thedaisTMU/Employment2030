# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.feature_selection import mutual_info_classif, chi2, f_regression, mutual_info_regression, f_classif, SelectKBest
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import matplotlib.pyplot as plt

np.random.seed(1000)

# %% [markdown]
# *Processing Data*
#
# the below function reads the data file and creats 3 tables:
#     1. the x table - workshop number and rounded SAk scores
#     2. vector containing the indivual expert answers
#     3. vectors containing portion of experts that said answered each of the three possible answers

# %%
def data_proccess(file):
    data = pd.read_csv(file,index_col=['noc','workshop.number'])
    data.sort_index(inplace=True)
    data.loc[data.share == 'remain constant','share'] = 'constant'
        
    x = data.drop(['absolute','share','Unnamed: 0','noc_code'],axis=1) #making x data frame
    x['work_num'] = x.index.get_level_values(1) #making workshop number a variable as well as an index
    x = np.round(x).astype(int)#round x to make discrete
    
    x_agg = x.drop_duplicates()
    
    x_noclvl = x_agg.drop('work_num',axis=1).droplevel(1).drop_duplicates()
    
    y = pd.DataFrame({'non_binned': data['share'],
              'increase': data['share'].str.replace('constant','decrease'),
              'decrease': data['share'].str.replace('constant','increase')})

    y_agg = pd.DataFrame(data['share']).pivot_table(index = ['noc','workshop.number'], columns = 'share', aggfunc = len).fillna(0)
    y_agg['sum'] = y_agg.sum(axis = 1)
    y_noclvl = y_agg.groupby(level=0).sum()
    y_agg.loc[:,y_agg.columns!='sum'] = y_agg.loc[:,y_agg.columns!='sum'].divide(y_agg['sum'],axis=0)
    y_noclvl.loc[:,y_noclvl.columns!='sum'] = y_noclvl.loc[:,y_noclvl.columns!='sum'].divide(y_noclvl['sum'],axis=0)
    
    
    
    return x, x_agg, y, y_agg, x_noclvl, y_noclvl

# %%
def init_params(model_type):
    if model_type == 'cat':
        params = {
         'criterion': 'gini',
         'max_features': 'auto',
         'min_samples_leaf': 4,
         'min_samples_split': 10,
         'n_estimators': 300,
         'n_jobs':-1
        }
    if model_type == 'reg':
        params = {
         'criterion': 'mse',
         'max_features': None,
         'min_samples_leaf': 2,
         'min_samples_split': 5,
         'n_estimators': 300,
         'n_jobs':-1
        }
    return params

# %%
def run_k_fold (x,y,params,index,binned,model_type):
    
    x = pd.DataFrame(x)
    
    rf = RandomForestClassifier(**params)
    kf = KFold(n_splits=10,shuffle=False)
    n_trees = params['n_estimators']
    
    if model_type == 'reg':
        rf = RandomForestRegressor(**params)
        kf = KFold(n_splits=5,shuffle=True)
    
    if binned:
        pred = np.zeros(x.shape[0])
    else:
        pred = np.zeros((x.shape[0],3))
    
    for train_index, test_index in kf.split(x):
        x_train, x_test = x.iloc[train_index], x.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        rf.fit(x_train,y_train)
        
        if model_type == 'reg':
            pred[test_index] = rf.predict(x_test)
        if model_type == 'pred_probs':
            if binned:
                pred[test_index] = rf.predict_proba(x_test)[:,0] #this is giving the decrease number, increase can be infered
            else:
                pred[test_index] = rf.predict_proba(x_test)
        if model_type == 'tree_port':
            tree_pred = np.zeros((n_trees,len(test_index))) 
            for tree in range(n_trees):
                tree_pred[tree] = rf.estimators_[tree].predict(x_test)
            pred[test_index] = tree_pred.mean(axis=0)
    
    pred = pd.DataFrame(pred,index=index).groupby(index).first()
    
    return pred

# %%
def param_search(x,y,params,model_type):
    
    rf = RandomForestClassifier(**params)
    
    if model_type == 'reg':
        rf = RandomForestRegressor(**params)
    
    param_grid= {'max_features':['sqrt',22,70,None],#number of features a tree selects 
             'n_estimators':[100,150,250,275,300],#number of trees 
             'min_samples_leaf': [1,2,4,8],#minimum number of data points can be used to make a leaf at the end of a tree 
             'min_samples_split': [5,10,15]#min number of data points to split a branch 
             }

    if model_type == 'reg':    
        param_grid['criterion'] = ['mae','mse']
    if model_type == 'cat':
        param_grid['criterion'] = ['gini','entropy']
    
    search = GridSearchCV(rf,param_grid,cv=5,n_jobs=-1,iid=False)
    search.fit(x,y)
    
    return search.best_params_, cv_results_

# %%
def basic_feature_selection(x,y,model_type,k):
    if model_type == 'class':
        return SelectKBest(mutual_info_classif,k).fit_transform(x,y)
#                SelectKBest(chi2,'all').fit(x,y),
#                SelectKBest(f_classif,'all').fit(x,y))
    if model_type == 'reg':
        return SelectKBest(mutual_info_regression,k).fit_transform(x,y)
#                SelectKBest(f_regression,'all').fit(x,y))

# %%
#Feature scores for a number of differnt measures
def different_feature_rankings(x, x_agg, y, y_agg):
    mi_class, chi2_class, f_class = basic_feature_selection(x,y['increase'],'class')
    mi_reg, f_reg = basic_feature_selection(x_agg,y_agg['increase'],'reg')
    
    feature_scores = pd.DataFrame({'mi_class': mi_class.scores_,
                 'chi2': chi2_class.scores_,
                 'f_class': f_class.scores_,
                 'mi_reg': mi_reg.scores_,
                 'f_reg': f_reg.scores_},index=x.columns)
    
    feature_scores.sort_values('mi_reg',ascending = False)

# %%
def scores_by_k(x, x_agg, y, y_agg):
    reg_scores = np.zeros((120,120))
    class_scores = np.zeros((120,120))

    for k in range(1,121):
        reg_scores[k] = run_k_fold(basic_feature_selection(x_agg,y_agg['increase'],'reg',k),
                            y_agg['increase'],
                            init_params('reg'),
                            x_agg.index,
                            'reg').iloc[:,0].values
        class_scores[k] = run_k_fold(basic_feature_selection(x,y['increase'],'class',k),
                            y['increase'],
                            init_params('cat'),
                            x.index,
                            'pred_probs').iloc[:,0].values
        
        r_scores = abs(pd.DataFrame(reg_scores,index=range(1,121),columns=x_agg.index).T.subtract(y_agg['increase'],axis=0)).mean(axis=0)
        c_scores = abs((1-pd.DataFrame(class_scores,index=range(1,121),columns=x_agg.index).T).subtract(y_agg['increase'],axis=0)).mean()
        
        return r_scores, c_scores

# %%
def run_models(x, x_agg, y, y_agg,binned,increase,k_reg,k_class):    
    
    if binned:
        if increase:
            #set number of features to run with
            x_agg_cut = basic_feature_selection(x_agg,y_agg['increase'],'reg',k_reg)
            x_cut = basic_feature_selection(x,y['increase'],'class',k_class)

            #run regression in a k-fold framework and place results into dataframes
            pred = pd.concat([
                run_k_fold(x_agg_cut,y_agg['increase'],init_params('reg'),x_agg.index,binned,'reg'),
                1 - run_k_fold(x_cut,y['increase'],init_params('cat'),x.index,binned,'pred_probs'),
                run_k_fold(x_cut,y['increase'],init_params('cat'),x.index,binned,'tree_port')
            ],axis=1)

        else:
            x_agg_cut = basic_feature_selection(x_agg,y_agg['decrease'],'reg',k_reg)
            x_cut = basic_feature_selection(x,y['decrease'],'class',k_class)

            #run regression in a k-fold framework and place results into dataframes
            pred = pd.concat([
                run_k_fold(x_agg_cut,y_agg['decrease'],init_params('reg'),x_agg.index,binned,'reg'),
                run_k_fold(x_cut,y['decrease'],init_params('cat'),x.index,binned,'pred_probs'),
                1 - run_k_fold(x_cut,y['decrease'],init_params('cat'),x.index,binned,'tree_port')
            ],axis=1)
        
    else:
        y_agg = y_agg[['constant','decrease','increase']]
        y = y['non_binned']
        pred = pd.concat([
            run_k_fold(x_agg,y_agg,init_params('reg'),x_agg.index,binned,'reg'),
            run_k_fold(x,y,init_params('cat'),x.index,binned,'pred_probs')#,
            #run_k_fold(x,y,init_params('cat'),x.index,binned,'tree_port')
        ],axis=1)
        
    
    pred.set_index(x_agg.index,inplace = True)
    if binned:
        pred.columns = ['regression','pred_prob','tree_portions']
    else:
        pred.columns = ['regression_con','regression_dec','regression_inc',
                                 'prob_con','prob_dec','prob_inc']
    
    return pred

# %%
def confusion_matrix(pred,truth,binned):
    if binned:
        matrix = pd.DataFrame(
         [[sum(np.logical_and(pred>=0.5,truth>=0.5)),
           sum(np.logical_and(pred>=0.5,truth<0.5))],
          [sum(np.logical_and(pred<0.5,truth>=0.5)),
           sum(np.logical_and(pred<0.5,truth<0.5))]]
        ,columns=['pred_increase','pred_decrease'],index=['true_increase','true_decrease'])
    else:
        pred.columns = ['constant','decrease','increase']
        matrix = pd.DataFrame(
        [[sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='increase')),
          sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='constant')),
          sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='decrease'))],
         [sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='increase')),
          sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='constant')),
          sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='decrease'))],
         [sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='increase')),
          sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='constant')),
          sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='decrease'))]],
        columns=['pred_increase','pred_constant','pred_decrease'],index=['true_increase','true_constant','true_decrease'])
        
    return matrix

# %%
#read data
file = "C:/Users/USERID/Documents/GitHub/Employment2030/Employment2030/tables/noc_answers.csv"
x, x_agg, y, y_agg, x_noclvl, y_noclvl = data_proccess(file)

#running initial models
# pred = run_models(x, x_agg, y, y_agg,False,True,120,120)
# increase_pred = run_increase_models(x, x_agg, y, y_agg,True,True,120,120)
# decrease_pred = run_increase_models(x, x_agg, y, y_agg,True,False,120,120)
# increase_noclvl_pred = run_k_fold(x_noclvl,y_noclvl['increase'],init_params('reg'),x_noclvl.index,True,'reg')
# decrease_noclvl_pred = run_k_fold(x_noclvl,y_noclvl['decrease'],init_params('reg'),x_noclvl.index,True,'reg')

y_agg = y_agg[['constant','decrease','increase']]

#getting accuracy scores
pred_acc = abs(pd.DataFrame(np.matrix(pred) 
                            - np.matrix(pd.concat([y_agg,y_agg],axis=1)),index=pred.index,columns=pred.columns))
increase_acc = abs(increase_pred.subtract(y_agg['increase'],axis=0))
decrease_acc = abs(decrease_pred.subtract(y_agg['decrease'],axis=0))
increase_noclvl_acc = abs(increase_noclvl_pred.subtract(y_noclvl['increase'],axis=0))
decrease_noclvl_acc = abs(decrease_noclvl_pred.subtract(y_noclvl['decrease'],axis=0))

#means and std deviations
performance = pd.concat([
    pd.concat([pred_acc.mean(),increase_acc.mean(),decrease_acc.mean(),
               increase_noclvl_acc.mean(),decrease_noclvl_acc.mean()]),
    pd.concat([pred_acc.std(),increase_acc.std(),decrease_acc.std(),
               increase_noclvl_acc.std(),decrease_noclvl_acc.std()])]
    ,axis=1)
performance.columns = ['mean','std']
performance.index = ['reg_con','reg_dec','reg_inc','prob_con','prob_dec','prob_inc',
                     'reg_bin_inc','prob_bin_inc','tree_bin_inc',
                     'reg_bin_dec','prob_bin_dec','tree_bin_dec',
                     'noclvl_inc','noclvl_dec']

#confusion matrices
pred_reg_confusion = confusion_matrix(pred[['regression_con','regression_dec','regression_inc']],y_agg,False)
pred_prob_confusion = confusion_matrix(pred[['pred_con','pred_dec','pred_inc']],y_agg,False)
inc_reg_confusion = confusion_matrix(increase_pred['regression'],y_agg['increase'],True)
inc_prob_confusion = confusion_matrix(increase_pred['pred_prob'],y_agg['increase'],True)
inc_tree_confusion = confusion_matrix(increase_pred['tree_portions'],y_agg['increase'],True)
dec_reg_confusion = confusion_matrix(decrease_pred['regression'],y_agg['decrease'],True)
dec_prob_confusion = confusion_matrix(decrease_pred['pred_prob'],y_agg['decrease'],True)
inc_tree_confusion = confusion_matrix(decrease_pred['tree_portions'],y_agg['decrease'],True)
#inc_noclvl_confusion = confusion_matrix(increase_noclvl_pred,y_noclvl['increase'],True)
#dec_noclvl_confusion = confusion_matrix(decrease_noclvl_pred,y_noclvl['increase'],True)

# %%
inc_tree_confusion
# Out:
#                pred_increase  pred_decrease
# true_increase             24              7
# true_decrease             18             71

# %%
pd.DataFrame(
 [[sum(np.logical_and(y_agg['increase']>=0.5,increase_pred['regression']>=0.5)),
  sum(np.logical_and(y_agg['increase']>=0.5,increase_pred['regression']<0.5))],
 [sum(np.logical_and(y_agg['increase']<0.5,increase_pred['regression']>=0.5)),
  sum(np.logical_and(y_agg['increase']<0.5,increase_pred['regression']<0.5))]]
,columns=['pred_increase','pred_decrease'],index=['true_increase','true_decrease'])
# Out:
#                pred_increase  pred_decrease
# true_increase             16             15
# true_decrease              5             84

# %%
pd.DataFrame(
 [[sum(np.logical_and(y_agg['increase']>=0.5,increase_pred['pred_prob']>=0.5)),
  sum(np.logical_and(y_agg['increase']>=0.5,increase_pred['pred_prob']<0.5))],
 [sum(np.logical_and(y_agg['increase']<0.5,increase_pred['pred_prob']>=0.5)),
  sum(np.logical_and(y_agg['increase']<0.5,increase_pred['pred_prob']<0.5))]]
,columns=['pred_increase','pred_decrease'],index=['true_increase','true_decrease'])
# Out:
#                pred_increase  pred_decrease
# true_increase             21             10
# true_decrease              7             82

# %%
truth = y_agg[['constant','decrease','increase']]
pred = increase_pred_not_bin[['regression_con','regression_dec','regression_inc']]
pd.DataFrame(
[[sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='regression_inc')),
  sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='regression_con')),
  sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='regression_dec'))],
 [sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='regression_inc')),
  sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='regression_con')),
  sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='regression_dec'))],
 [sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='regression_inc')),
  sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='regression_con')),
  sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='regression_dec'))]],
columns=['pred_increase','pred_constant','pred_decrease'],index=['true_increase','true_constant','true_decrease'])
# Out:
#                pred_increase  pred_constant  pred_decrease
# true_increase             30              4              3
# true_constant             12              7              9
# true_decrease              6              3             46

# %%
truth = y_agg[['constant','decrease','increase']]
pred = increase_pred_not_bin[['pred_con','pred_dec','pred_inc']]
pd.DataFrame(
[[sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='pred_inc')),
  sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='pred_con')),
  sum(np.logical_and(truth.idxmax(axis=1)=='increase',pred.idxmax(axis=1)=='pred_dec'))],
 [sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='pred_inc')),
  sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='pred_con')),
  sum(np.logical_and(truth.idxmax(axis=1)=='constant',pred.idxmax(axis=1)=='pred_dec'))],
 [sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='pred_inc')),
  sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='pred_con')),
  sum(np.logical_and(truth.idxmax(axis=1)=='decrease',pred.idxmax(axis=1)=='pred_dec'))]],
columns=['pred_increase','pred_constant','pred_decrease'],index=['true_increase','true_constant','true_decrease'])
# Out:
#                pred_increase  pred_constant  pred_decrease
# true_increase             33              3              1
# true_constant             20              3              5
# true_decrease             17              3             35

# %%
increase_pred_not_bin[['regression_con','regression_dec','regression_inc',]].idxmax(axis=1)
# Out:
# noc                                                                            workshop.number
# Accommodation service managers                                                 4                  regression_inc
# Accounting technicians and bookkeepers                                         4                  regression_dec
# Air pilots, flight engineers and flying instructors                            3                  regression_inc
# Air transport ramp attendants                                                  3                  regression_dec
# Airline ticket and service agents                                              3                  regression_inc
# Carpenters                                                                     3                  regression_con
# Central control and process operators, petroleum, gas and chemical processing  1                  regression_dec
# Chefs                                                                          4                  regression_inc
# Computer network technicians                                                   1                  regression_inc
#                                                                                2                  regression_inc
#                                                                                3                  regression_inc
#                                                                                4                  regression_inc
#                                                                                5                  regression_inc
#                                                                                6                  regression_inc
# Cooks                                                                          5                  regression_dec
# Correctional service officers                                                  3                  regression_con
# Court clerks                                                                   1                  regression_dec
#                                                                                2                  regression_dec
#                                                                                3                  regression_dec
#                                                                                4                  regression_dec
#                                                                                5                  regression_dec
#                                                                                6                  regression_dec
# Delivery and courier service drivers                                           5                  regression_dec
# Electrical mechanics                                                           1                  regression_inc
#                                                                                2                  regression_inc
#                                                                                3                  regression_inc
#                                                                                4                  regression_inc
#                                                                                5                  regression_inc
#                                                                                6                  regression_inc
# Financial managers                                                             1                  regression_dec
#                                                                                                        ...
# Plastics processing machine operators                                          2                  regression_dec
#                                                                                3                  regression_dec
#                                                                                4                  regression_dec
#                                                                                5                  regression_dec
#                                                                                6                  regression_dec
# Real estate agents and salespersons                                            2                  regression_inc
# Registered nurses and registered psychiatric nurses                            6                  regression_inc
# Restaurant and food service managers                                           2                  regression_inc
# Senior managers - financial, communications and other business services        1                  regression_con
#                                                                                2                  regression_con
#                                                                                3                  regression_con
#                                                                                4                  regression_con
#                                                                                5                  regression_con
#                                                                                6                  regression_con
# Shippers and receivers                                                         5                  regression_dec
# Steamfitters, pipefitters and sprinkler system installers                      6                  regression_inc
# Store shelf stockers, clerks and order fillers                                 5                  regression_dec
# Supervisors, petroleum, gas and chemical processing and utilities              1                  regression_inc
#                                                                                2                  regression_inc
#                                                                                3                  regression_con
#                                                                                4                  regression_inc
#                                                                                5                  regression_inc
#                                                                                6                  regression_dec
# Technical sales specialists - wholesale trade                                  2                  regression_inc
# Underground production and development miners                                  1                  regression_dec
#                                                                                2                  regression_dec
#                                                                                3                  regression_dec
#                                                                                4                  regression_dec
#                                                                                5                  regression_dec
#                                                                                6                  regression_dec
# Length: 120, dtype: object

# %%
,columns=['pred_increase','pred_constant','pred_decrease'],index=['true_increase','true_constant','true_decrease')
# Out:
# (120,)

# %%
#overall increase accuracy for seleted features
print(increase_acc.mean())
print(increase_acc.std())
# Out:
# regression       0.132067
# pred_prob        0.151442
# tree_portions    0.202515
# dtype: float64
# regression       0.125863
# pred_prob        0.120814
# tree_portions    0.171395
# dtype: float64

# %%
print(np.argmin(r_scores))
print(np.argmin(c_scores))
# Out:
# 104
# 18
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:56: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   return getattr(obj, method)(*args, **kwds)

# %%
plt.plot(range(2,121),r_scores[1:])

# %%
plt.plot(range(2,121),c_scores[1:])

# %%
feature_scores.sort_values('mi_reg',ascending = False)
# Out:
#                                      mi_class       chi2     f_class  \
# value.Service Orientation            0.015444  22.130551  162.539993
# value.Fluency of Ideas               0.045665  17.536596  148.740250
# value.Persuasion                     0.050789  16.669440  132.447418
# value.Instructing                    0.047202  15.701828  152.591324
# value.Customer and Personal Service  0.034084  20.326592   91.567215
# value.Law and Government             0.016165   0.502573    1.783792
# value.Technology Design              0.046398  32.831573  174.829971
# value.Computers and Electronics      0.038917  20.136260  123.476646
# value.Memorization                   0.044722  14.068275  167.149246
# value.Systems Evaluation             0.015011  24.238534  154.402130
# value.Control Precision              0.014195   9.475285   33.757072
# value.Depth Perception               0.006255   0.208582    1.080126
# value.Trunk Strength                 0.000000   0.517509    2.115180
# value.Problem Sensitivity            0.005093   4.603557   83.418419
# value.Active Learning                0.000000   6.197103   53.989799
# value.Finger Dexterity               0.023510   0.005075    0.039402
# value.Originality                    0.046907  14.494931  114.466171
# value.Rate Control                   0.019959   9.817743   36.853233
# value.Critical Thinking              0.021571   7.064338  106.195412
# value.Administration and Management  0.015362   2.565483   18.621338
# value.Speech Clarity                 0.000000   0.770018   10.765679
# value.Philosophy and Theology        0.006472   5.325594   29.192942
# value.Psychology                     0.013857  11.771406   54.412170
# value.Repairing                      0.013749   0.373505    0.765423
# value.Reaction Time                  0.023711  11.833792   33.705002
# value.Physics                        0.005700   0.280272    1.098556
# value.Inductive Reasoning            0.033012   4.613632   66.459747
# value.Therapy and Counseling         0.000000   3.733240   10.682860
# value.Economics and Accounting       0.014220   0.114222    0.440203
# value.Time Management                0.014084   1.212864   16.782473
# ...                                       ...        ...         ...
# value.Mathematics Knowledge          0.014542   0.626038    8.438636
# value.Medicine and Dentistry         0.007741   0.189413    0.412557
# value.Reading Comprehension          0.000000   2.787982   35.611752
# value.Production and Processing      0.000000   0.355264    1.238335
# value.Visualization                  0.000954   2.496021   27.520151
# value.Writing                        0.010660   1.768725   12.040013
# value.Mathematics Skill              0.014817   4.616707   46.547234
# value.Social Perceptiveness          0.000000   0.789301   11.295801
# value.Operations Analysis            0.011391   5.343828   50.265167
# value.Equipment Selection            0.000035   0.709411    2.632650
# value.Equipment Maintenance          0.000000   2.734947    6.970646
# value.Oral Comprehension             0.003236   1.747357   31.113569
# value.Oral Expression                0.001836   1.571977   25.615452
# value.Flexibility of Closure         0.000000   0.302315    4.979916
# value.Perceptual Speed               0.004328   0.000362    0.013299
# value.Spatial Orientation            0.000000   5.553220   16.147408
# value.Speed of Limb Movement         0.003494   2.593842   15.723783
# value.Sales and Marketing            0.000000   7.042012   33.636818
# value.Explosive Strength             0.000000   0.000002    0.000000
# value.Stamina                        0.004165  13.591379   46.975609
# value.Extent Flexibility             0.012302   4.605113   15.077932
# value.Dynamic Flexibility            0.011468   0.099196    4.073577
# value.Gross Body Coordination        0.010544   5.816551   26.851665
# value.Gross Body Equilibrium         0.020865   6.857305   40.673798
# value.Night Vision                   0.012017   6.226109   30.458239
# value.Peripheral Vision              0.017298   5.063967   24.976530
# value.Glare Sensitivity              0.009320   5.464282   26.982695
# value.Sound Localization             0.010432   6.325267   33.050068
# value.Speech Recognition             0.000000   0.192898    2.694248
# value.Multilimb Coordination         0.000900   4.211766   12.096374
#
#                                        mi_reg      f_reg
# value.Service Orientation            0.186717  33.681683
# value.Fluency of Ideas               0.181461  31.570130
# value.Persuasion                     0.179115  27.163106
# value.Instructing                    0.164188  30.849780
# value.Customer and Personal Service  0.160189  17.937307
# value.Law and Government             0.158381   0.488624
# value.Technology Design              0.151045  37.180378
# value.Computers and Electronics      0.149810  25.055982
# value.Memorization                   0.145205  34.557723
# value.Systems Evaluation             0.140245  32.283791
# value.Control Precision              0.139175   5.966898
# value.Depth Perception               0.132486   0.167743
# value.Trunk Strength                 0.128652   0.272600
# value.Problem Sensitivity            0.126800  14.635346
# value.Active Learning                0.117776   9.574259
# value.Finger Dexterity               0.117571   0.001455
# value.Originality                    0.107616  23.040458
# value.Rate Control                   0.107259   6.110426
# value.Critical Thinking              0.107212  19.582915
# value.Administration and Management  0.107179   2.895073
# value.Speech Clarity                 0.103491   1.316656
# value.Philosophy and Theology        0.098809   5.129261
# value.Psychology                     0.098475   8.694584
# value.Repairing                      0.097316   0.090906
# value.Reaction Time                  0.096060   6.083271
# value.Physics                        0.094687   0.106572
# value.Inductive Reasoning            0.093387  11.347939
# value.Therapy and Counseling         0.084610   1.382127
# value.Economics and Accounting       0.082171   0.027163
# value.Time Management                0.080426   3.054967
# ...                                       ...        ...
# value.Mathematics Knowledge          0.000000   0.897816
# value.Medicine and Dentistry         0.000000   0.000002
# value.Reading Comprehension          0.000000   4.822080
# value.Production and Processing      0.000000   0.223297
# value.Visualization                  0.000000   5.319412
# value.Writing                        0.000000   1.870081
# value.Mathematics Skill              0.000000   8.315989
# value.Social Perceptiveness          0.000000   1.605058
# value.Operations Analysis            0.000000   8.949843
# value.Equipment Selection            0.000000   0.578024
# value.Equipment Maintenance          0.000000   1.103930
# value.Oral Comprehension             0.000000   4.735699
# value.Oral Expression                0.000000   3.943248
# value.Flexibility of Closure         0.000000   0.751123
# value.Perceptual Speed               0.000000   0.001395
# value.Spatial Orientation            0.000000   3.310092
# value.Speed of Limb Movement         0.000000   2.940386
# value.Sales and Marketing            0.000000   6.430853
# value.Explosive Strength             0.000000   0.001631
# value.Stamina                        0.000000   8.429240
# value.Extent Flexibility             0.000000   2.633645
# value.Dynamic Flexibility            0.000000   1.191697
# value.Gross Body Coordination        0.000000   5.161237
# value.Gross Body Equilibrium         0.000000   7.361524
# value.Night Vision                   0.000000   5.587963
# value.Peripheral Vision              0.000000   4.766006
# value.Glare Sensitivity              0.000000   4.922165
# value.Sound Localization             0.000000   6.331052
# value.Speech Recognition             0.000000   0.248127
# value.Multilimb Coordination         0.000000   2.190866
#
# [121 rows x 5 columns]

# %%
plt.plot(y_agg['increase'],increase_acc['regression'],'bo')

# %%
plt.plot(y_agg['increase'],increase_acc['pred_prob'],'bo')

# %%
plt.plot(y_agg['increase'],increase_acc['tree_portions'],'bo')

# %%
plt.plot(y_agg['decrease'],decrease_acc['regression'],'bo')

# %%
increase_acc.sort_values('pred_prob',ascending=False)
# Out:
#                                                                     regression  \
# noc                                                workshop.number
# Cooks                                              5                  0.486855
# Graphic designers and illustrators                 4                  0.495538
# Chefs                                              4                  0.497065
# Medical administrative assistants                  5                  0.224135
# Airline ticket and service agents                  3                  0.493361
# Supervisors, petroleum, gas and chemical proces... 3                  0.321110
# Operators and attendants in amusement, recreati... 6                  0.237973
# Medical administrative assistants                  6                  0.110938
# Forestry technologists and technicians             4                  0.293192
# Health policy researchers, consultants and prog... 2                  0.343806
# Managers in agriculture                            1                  0.261955
# Medical administrative assistants                  2                  0.013293
#                                                    1                  0.058317
# Technical sales specialists - wholesale trade      2                  0.354887
# Senior managers - financial, communications and... 2                  0.211627
# Supervisors, petroleum, gas and chemical proces... 6                  0.312211
# Computer network technicians                       3                  0.183039
# Oil and gas well drillers, servicers, testers a... 1                  0.402286
# Financial managers                                 5                  0.173731
# Forestry technologists and technicians             5                  0.174717
# Financial managers                                 6                  0.178068
# Court clerks                                       1                  0.090062
# Medical administrative assistants                  4                  0.137829
# Senior managers - financial, communications and... 5                  0.150407
# Computer network technicians                       4                  0.095489
# Operators and attendants in amusement, recreati... 5                  0.064419
# Industrial and manufacturing engineers             2                  0.190364
# Operators and attendants in amusement, recreati... 1                  0.140751
# Court clerks                                       3                  0.091231
# Senior managers - financial, communications and... 3                  0.014825
# ...                                                                        ...
# Computer network technicians                       6                  0.045016
# Labourers in food, beverage and associated prod... 4                  0.067344
#                                                    5                  0.019249
#                                                    3                  0.043448
# Furniture and fixture assemblers and inspectors    4                  0.067391
# Supervisors, petroleum, gas and chemical proces... 1                  0.077420
# Furniture and fixture assemblers and inspectors    6                  0.029402
# Forestry technologists and technicians             1                  0.157496
# Electrical mechanics                               2                  0.006687
# Accounting technicians and bookkeepers             4                  0.054734
# Computer network technicians                       5                  0.252740
# Supervisors, petroleum, gas and chemical proces... 2                  0.060912
# Plastics processing machine operators              3                  0.091943
# Underground production and development miners      5                  0.034399
# Plastics processing machine operators              5                  0.082884
# Shippers and receivers                             5                  0.009457
# Fish and seafood plant workers                     6                  0.041900
# Underground production and development miners      3                  0.059163
# Computer network technicians                       2                  0.190396
# Restaurant and food service managers               2                  0.051405
# Court clerks                                       6                  0.139839
# Underground production and development miners      4                  0.033535
# Labourers in food, beverage and associated prod... 1                  0.003924
# Registered nurses and registered psychiatric nu... 6                  0.467505
# Electrical mechanics                               4                  0.067624
# Air pilots, flight engineers and flying instruc... 3                  0.083484
# Instructors of persons with disabilities           2                  0.209716
# Air transport ramp attendants                      3                  0.042754
# Fishermen/women                                    6                  0.242097
# Industrial and manufacturing engineers             3                  0.150590
#
#                                                                     pred_prob  \
# noc                                                workshop.number
# Cooks                                              5                 0.539231
# Graphic designers and illustrators                 4                 0.522421
# Chefs                                              4                 0.519282
# Medical administrative assistants                  5                 0.493821
# Airline ticket and service agents                  3                 0.481606
# Supervisors, petroleum, gas and chemical proces... 3                 0.425032
# Operators and attendants in amusement, recreati... 6                 0.419434
# Medical administrative assistants                  6                 0.394044
# Forestry technologists and technicians             4                 0.392270
# Health policy researchers, consultants and prog... 2                 0.388400
# Managers in agriculture                            1                 0.384532
# Medical administrative assistants                  2                 0.381431
#                                                    1                 0.375658
# Technical sales specialists - wholesale trade      2                 0.365603
# Senior managers - financial, communications and... 2                 0.355171
# Supervisors, petroleum, gas and chemical proces... 6                 0.343441
# Computer network technicians                       3                 0.339817
# Oil and gas well drillers, servicers, testers a... 1                 0.322483
# Financial managers                                 5                 0.311701
# Forestry technologists and technicians             5                 0.299867
# Financial managers                                 6                 0.291288
# Court clerks                                       1                 0.289766
# Medical administrative assistants                  4                 0.266329
# Senior managers - financial, communications and... 5                 0.264766
# Computer network technicians                       4                 0.260870
# Operators and attendants in amusement, recreati... 5                 0.254851
# Industrial and manufacturing engineers             2                 0.253864
# Operators and attendants in amusement, recreati... 1                 0.247336
# Court clerks                                       3                 0.243349
# Senior managers - financial, communications and... 3                 0.239453
# ...                                                                       ...
# Computer network technicians                       6                 0.051178
# Labourers in food, beverage and associated prod... 4                 0.050263
#                                                    5                 0.049050
#                                                    3                 0.046916
# Furniture and fixture assemblers and inspectors    4                 0.045608
# Supervisors, petroleum, gas and chemical proces... 1                 0.044043
# Furniture and fixture assemblers and inspectors    6                 0.042243
# Forestry technologists and technicians             1                 0.032220
# Electrical mechanics                               2                 0.031814
# Accounting technicians and bookkeepers             4                 0.030235
# Computer network technicians                       5                 0.026850
# Supervisors, petroleum, gas and chemical proces... 2                 0.022502
# Plastics processing machine operators              3                 0.022231
# Underground production and development miners      5                 0.020517
# Plastics processing machine operators              5                 0.020415
# Shippers and receivers                             5                 0.019026
# Fish and seafood plant workers                     6                 0.018680
# Underground production and development miners      3                 0.018476
# Computer network technicians                       2                 0.018235
# Restaurant and food service managers               2                 0.016081
# Court clerks                                       6                 0.014033
# Underground production and development miners      4                 0.011569
# Labourers in food, beverage and associated prod... 1                 0.010424
# Registered nurses and registered psychiatric nu... 6                 0.010248
# Electrical mechanics                               4                 0.008951
# Air pilots, flight engineers and flying instruc... 3                 0.006463
# Instructors of persons with disabilities           2                 0.004421
# Air transport ramp attendants                      3                 0.003715
# Fishermen/women                                    6                 0.001936
# Industrial and manufacturing engineers             3                 0.001115
#
#                                                                     tree_portions
# noc                                                workshop.number
# Cooks                                              5                     0.483333
# Graphic designers and illustrators                 4                     0.494737
# Chefs                                              4                     0.604737
# Medical administrative assistants                  5                     0.660000
# Airline ticket and service agents                  3                     0.640000
# Supervisors, petroleum, gas and chemical proces... 3                     0.640000
# Operators and attendants in amusement, recreati... 6                     0.676087
# Medical administrative assistants                  6                     0.539565
# Forestry technologists and technicians             4                     0.300000
# Health policy researchers, consultants and prog... 2                     0.362609
# Managers in agriculture                            1                     0.357143
# Medical administrative assistants                  2                     0.629565
#                                                    1                     0.577143
# Technical sales specialists - wholesale trade      2                     0.419130
# Senior managers - financial, communications and... 2                     0.396087
# Supervisors, petroleum, gas and chemical proces... 6                     0.535217
# Computer network technicians                       3                     0.490000
# Oil and gas well drillers, servicers, testers a... 1                     0.232381
# Financial managers                                 5                     0.273333
# Forestry technologists and technicians             5                     0.233333
# Financial managers                                 6                     0.233043
# Court clerks                                       1                     0.110000
# Medical administrative assistants                  4                     0.466842
# Senior managers - financial, communications and... 5                     0.260000
# Computer network technicians                       4                     0.411053
# Operators and attendants in amusement, recreati... 5                     0.506667
# Industrial and manufacturing engineers             2                     0.259130
# Operators and attendants in amusement, recreati... 1                     0.429048
# Court clerks                                       3                     0.110000
# Senior managers - financial, communications and... 3                     0.160000
# ...                                                                           ...
# Computer network technicians                       6                     0.284783
# Labourers in food, beverage and associated prod... 4                     0.035263
#                                                    5                     0.130000
#                                                    3                     0.080000
# Furniture and fixture assemblers and inspectors    4                     0.042632
# Supervisors, petroleum, gas and chemical proces... 1                     0.188095
# Furniture and fixture assemblers and inspectors    6                     0.043478
# Forestry technologists and technicians             1                     0.033333
# Electrical mechanics                               2                     0.038696
# Accounting technicians and bookkeepers             4                     0.002105
# Computer network technicians                       5                     0.123333
# Supervisors, petroleum, gas and chemical proces... 2                     0.220870
# Plastics processing machine operators              3                     0.170000
# Underground production and development miners      5                     0.123333
# Plastics processing machine operators              5                     0.103333
# Shippers and receivers                             5                     0.026667
# Fish and seafood plant workers                     6                     0.066957
# Underground production and development miners      3                     0.130000
# Computer network technicians                       2                     0.163913
# Restaurant and food service managers               2                     0.158261
# Court clerks                                       6                     0.190870
# Underground production and development miners      4                     0.107895
# Labourers in food, beverage and associated prod... 1                     0.035238
# Registered nurses and registered psychiatric nu... 6                     0.173913
# Electrical mechanics                               4                     0.178421
# Air pilots, flight engineers and flying instruc... 3                     0.010000
# Instructors of persons with disabilities           2                     0.121304
# Air transport ramp attendants                      3                     0.070000
# Fishermen/women                                    6                     0.000000
# Industrial and manufacturing engineers             3                     0.030000
#
# [120 rows x 3 columns]
