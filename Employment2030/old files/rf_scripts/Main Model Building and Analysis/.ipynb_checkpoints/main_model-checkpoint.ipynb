# %%
# %run ../utils_rf.py
import csv

# %%
#read training data
file = "../../../tables/model_input/noc_answers.csv"
x, x_agg, y, y_agg, x_noclvl, y_noclvl = data_proccess(file,True)

#grab just the noc codes to cut out test nocs from main noc table
train_nocs = pd.read_csv(file,usecols=['noc_code']).drop_duplicates()

# %%
y_noclvl.to_csv(r'../../../tables/model_output/train_occupation_probs.csv'
                 ,index=True,header=True)

# %%
#read full noc set
file ="../../../tables/model_input/noc_scores.csv"
nocs = pd.read_csv(file,index_col=['noc'])
nocs.sort_index(inplace=True)
nocs.drop(['Unnamed: 0'],axis=1,inplace=True)
nocs = np.round(nocs).astype(int)
nocs.drop(train_nocs['noc_code'],inplace=True)

# %% [markdown]
# *Test using Chosen Model in this script before full training and prediction*
#
# Also I should make the feature be read from a file

# %%
sffs_prob_features = ('value.Service Orientation',
'value.Computers and Electronics',
'value.Chemistry',
'value.Information Ordering',
'value.Monitoring',
'value.Time Sharing',
'value.Management of Material Resources',
'value.Flexibility of Closure',
'value.Persuasion',
'value.Memorization',
'value.Finger Dexterity',
'value.Learning Strategies',
'value.Far Vision',
'value.Biology')

# %%
means = []
models = []
for i in range(10):    
    inc_prob_sfs = run_k_fold(x.loc[:,sffs_prob_features],y['increase'],init_params('cat'),x.index,True,'pred_probs')
    means.append(abs(inc_prob_sfs.subtract(y_noclvl['increase'],axis=0)).mean())
    models.append(inc_prob_sfs)

# %%
inc_prob_sfs = models[np.argmin(means)].copy()

# %%
np.mean(means)
# Out:
# 0.12541005898984137

# %%
bins=np.histogram(np.hstack((y_noclvl['increase'],inc_prob_sfs[0])), bins=20)[1]#switch to y_agg if doing workshop lvl

fig, ax = plt.subplots()
plt.hist(y_noclvl['increase'],bins, alpha = 0.5, edgecolor = 'black',label='True')
#plt.hist(inc_prob_sfs[0],bins, alpha = 0.25, edgecolor = 'black',label='Pred')
plt.legend(loc='upper right')
ax.set_ylabel('Count')
ax.set_title('Distibution True vs Predicted Increase Portions - Increase')

plt.savefig('true vs pred error.png')
plt.show()

# %%
inc_prob_sfs.to_csv('inc_trainset_projections.csv')

# %%
inc_prob_confusion = confusion_matrix(inc_prob_sfs[0],y_noclvl['increase'],True)
inc_prob_confusion
# Out:
#                pred_increase  pred_decrease
# true_increase              7              5
# true_decrease              0             33

# %%
correct_sum = 0
for i in range(2):
    correct_sum+=inc_prob_confusion.iloc[i,i]
correct_sum/45
# Out:
# 0.8666666666666667

# %%
inc_prob_confusion = confusion_matrix(inc_prob_sfs[0],y_noclvl['increase'],3)
inc_prob_confusion
# Out:
#                 pred>=0.7  0.5<=pred<0.7  0.3<=pred<0.5  pred<0.3
# truth>=0.7              0              3              3         1
# 0.5<=truth<0.7          0              4              1         0
# 0.3<=truth<0.5          0              0              6         2
# truth<0.3               0              0              7        18

# %%
correct_sum = 0
for i in range(4):
    correct_sum+=inc_prob_confusion.iloc[i,i]
correct_sum/45
# Out:
# 0.6222222222222222

# %%
true_labels = y_noclvl['increase'].where(y_noclvl['increase']>=0.5,0).where(y_noclvl['increase']<0.5,1)
fpr, tpr, thresholds = roc_curve(true_labels,inc_prob_sfs[0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, lw=1,label='ROC fold %d (AUC = %0.2f)' % (5, roc_auc))
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic - Increase Model')
plt.legend(loc="lower right")
plt.savefig('roc.png')
plt.show()

# %%
np.savetxt("inc_fpr.csv", fpr, delimiter=",")
np.savetxt("inc_tpr.csv", tpr, delimiter=",")

# %% [markdown]
# Next we will see what this model is bad at predicting

# %%
inc_prob_sfs_acc = abs(inc_prob_sfs.subtract(y_noclvl['increase'],axis=0))
inc_prob_sfs_acc['true'] = y_noclvl['increase']
inc_prob_sfs_acc['pred'] = inc_prob_sfs
inc_prob_sfs_acc.rename(columns={0: "abs_error"},inplace=True)
inc_prob_sfs_acc.sort_values('abs_error',ascending=False,inplace=True)

# %%
#the highest absolute error
inc_prob_sfs_acc[0:10]
# Out:
#                                                     abs_error      true  \
# noc
# Light duty cleaners                                  0.542506  0.733333
# Chefs                                                0.425140  0.894737
# Airline ticket and service agents                    0.416688  0.050000
# Graphic designers and illustrators                   0.415725  0.894737
# Technical sales specialists - wholesale trade        0.379214  0.739130
# Cooks                                                0.332645  0.733333
# Carpenters                                           0.281667  0.450000
# Health policy researchers, consultants and prog...   0.240479  0.782609
# Oil and gas well drillers, servicers, testers a...   0.213660  0.047619
# Store shelf stockers, clerks and order fillers       0.209462  0.066667
#
#                                                         pred
# noc
# Light duty cleaners                                 0.190827
# Chefs                                               0.469597
# Airline ticket and service agents                   0.466688
# Graphic designers and illustrators                  0.479012
# Technical sales specialists - wholesale trade       0.359916
# Cooks                                               0.400688
# Carpenters                                          0.168333
# Health policy researchers, consultants and prog...  0.542130
# Oil and gas well drillers, servicers, testers a...  0.261279
# Store shelf stockers, clerks and order fillers      0.276129

# %%
#what is wrong as a classifier
inc_prob_sfs_acc.loc[np.logical_or(
    np.logical_and(inc_prob_sfs_acc.true>=0.5,inc_prob_sfs_acc.pred<0.5),
    np.logical_and(inc_prob_sfs_acc.true<0.5,inc_prob_sfs_acc.pred>=0.5))]
# Out:
#                                                     abs_error      true  \
# noc
# Light duty cleaners                                  0.542506  0.733333
# Chefs                                                0.425140  0.894737
# Graphic designers and illustrators                   0.415725  0.894737
# Technical sales specialists - wholesale trade        0.379214  0.739130
# Cooks                                                0.332645  0.733333
# Air pilots, flight engineers and flying instruc...   0.100588  0.400000
#
#                                                         pred
# noc
# Light duty cleaners                                 0.190827
# Chefs                                               0.469597
# Graphic designers and illustrators                  0.479012
# Technical sales specialists - wholesale trade       0.359916
# Cooks                                               0.400688
# Air pilots, flight engineers and flying instruc...  0.500588

# %% [markdown]
# Next we train on the whole training set

# %%
nocs = nocs.loc[:,sffs_prob_features].copy()

rf = RandomForestClassifier(**init_params('cat'))
rf.fit(x.loc[:,sffs_prob_features],y['increase'])
noc_preds = pd.Series(rf.predict_proba(nocs)[:,0],index=nocs.index)

# %%
plt.plot(np.sort(noc_preds))
plt.show()

# %%
plt.hist(np.sort(noc_preds),20, alpha = 0.5, edgecolor = 'black')
plt.show()

# %%
print(sum(noc_preds>=0.7)/noc_preds.shape[0])
print(sum(np.logical_and(noc_preds>=0.5,noc_preds<0.7))/noc_preds.shape[0])
print(sum(np.logical_and(noc_preds>=0.3,noc_preds<0.5))/noc_preds.shape[0])
print(sum(noc_preds<0.3)/noc_preds.shape[0])
# Out:
# 0.029545454545454545
# 0.1590909090909091
# 0.46136363636363636
# 0.35

# %%
print(sum(y_noclvl['increase']>=0.7)/y_noclvl['increase'].shape[0])
print(sum(np.logical_and(y_noclvl['increase']>=0.5,y_noclvl['increase']<0.7))/y_noclvl['increase'].shape[0])
print(sum(np.logical_and(y_noclvl['increase']>=0.3,y_noclvl['increase']<0.5))/y_noclvl['increase'].shape[0])
print(sum(y_noclvl['increase']<0.3)/y_noclvl['increase'].shape[0])
# Out:
# 0.15555555555555556
# 0.1111111111111111
# 0.17777777777777778
# 0.5555555555555556

# %%
noc_preds.sort_values(ascending=False)
# Out:
# noc
# 8252    0.841524
# 3131    0.836523
# 3111    0.826728
# 8211    0.825357
# 5221    0.809459
# 3221    0.776229
# 3113    0.776229
# 2143    0.736249
# 2144    0.736249
# 2145    0.734025
# 3214    0.733419
# 211     0.711524
# 3132    0.711125
# 1113    0.696058
# 2147    0.687551
# 5223    0.685993
# 2263    0.682359
# 2134    0.667260
# 2121    0.666673
# 4167    0.661948
# 1423    0.654491
# 2175    0.653445
# 2242    0.647095
# 2255    0.642946
# 2161    0.641094
# 2233    0.638063
# 2112    0.638063
# 1114    0.633292
# 432     0.631492
# 1314    0.631060
#           ...
# 1432    0.105749
# 9441    0.100169
# 9445    0.100169
# 7531    0.099215
# 9432    0.097653
# 9411    0.090843
# 9231    0.090843
# 9235    0.085042
# 7611    0.085042
# 8615    0.075830
# 7372    0.067478
# 7373    0.067478
# 6332    0.066106
# 9537    0.066106
# 9535    0.066106
# 9415    0.066106
# 9527    0.066106
# 9525    0.066106
# 9416    0.066106
# 9523    0.066106
# 2262    0.066106
# 9447    0.066106
# 9465    0.066106
# 7442    0.057112
# 9526    0.047113
# 9522    0.047113
# 9418    0.047113
# 9413    0.047113
# 8261    0.001709
# 8441    0.001709
# Length: 440, dtype: float64

# %%
noc_preds[2262]
# Out:
# 0.06610554846120446

# %%
noc_preds.to_csv(r'../../tables/preojections.csv'
                 ,index=True,header=True)

# %% [markdown]
# ok now for some robustness we will run the model 10 times and see if there is a signifiant difference in predictions and ordering of nocs

# %%
robust_check = pd.DataFrame()

for i in range(10):
    rf = RandomForestClassifier(**init_params('cat'))
    rf.fit(x.loc[:,sffs_prob_features],y['increase'])
    robust_check[i] = pd.Series(rf.predict_proba(nocs)[:,0],index=nocs.index)

# %%
robust_check
# Out:
#              0         1         2         3         4         5         6  \
# noc
# 12    0.288076  0.289607  0.286917  0.290013  0.289723  0.286247  0.288375
# 14    0.288076  0.289607  0.286917  0.290013  0.289723  0.286247  0.288375
# 15    0.414214  0.418721  0.407669  0.409406  0.410081  0.383461  0.427246
# 16    0.288076  0.289607  0.286917  0.290013  0.289723  0.286247  0.288375
# 112   0.256521  0.273883  0.253162  0.257782  0.252382  0.262808  0.275785
# 113   0.399489  0.405805  0.407122  0.393664  0.404688  0.370973  0.393117
# 114   0.474122  0.499217  0.473972  0.447578  0.454092  0.463471  0.468652
# 121   0.283770  0.293338  0.308879  0.298992  0.315253  0.285412  0.311323
# 122   0.222588  0.220575  0.223097  0.220610  0.224664  0.226716  0.224860
# 124   0.438364  0.450631  0.435685  0.430288  0.420353  0.430907  0.449386
# 125   0.529107  0.535844  0.507094  0.529058  0.534070  0.543904  0.552044
# 131   0.489522  0.469796  0.489063  0.485292  0.496499  0.514497  0.491531
# 132   0.555701  0.530242  0.563818  0.530760  0.528519  0.525158  0.560960
# 211   0.722931  0.705554  0.710043  0.714072  0.737411  0.731931  0.738656
# 212   0.409624  0.377509  0.387566  0.417259  0.438782  0.386322  0.439839
# 213   0.582202  0.553152  0.568200  0.568565  0.575304  0.578696  0.582950
# 311   0.590303  0.538261  0.561001  0.590060  0.572600  0.550390  0.595526
# 414   0.310251  0.272934  0.287474  0.290677  0.304931  0.272843  0.312667
# 421   0.371316  0.374181  0.365842  0.379269  0.376670  0.374152  0.372458
# 422   0.434269  0.438609  0.444229  0.444745  0.459844  0.442798  0.436198
# 423   0.436445  0.459608  0.460290  0.467567  0.455428  0.452421  0.446466
# 431   0.482257  0.495502  0.498682  0.494317  0.486979  0.519062  0.485557
# 432   0.640904  0.634281  0.607398  0.637092  0.622007  0.612926  0.643437
# 512   0.480851  0.475121  0.504977  0.455184  0.477167  0.475046  0.501499
# 513   0.287533  0.293982  0.276292  0.271853  0.268157  0.285321  0.275268
# 601   0.383047  0.415187  0.383049  0.388162  0.385516  0.409757  0.411664
# 621   0.277929  0.282696  0.286874  0.288663  0.302570  0.287137  0.279268
# 651   0.335988  0.344179  0.341684  0.379056  0.362483  0.374342  0.366085
# 711   0.277929  0.282696  0.286874  0.288663  0.302570  0.287137  0.279268
# 712   0.277929  0.282696  0.286874  0.288663  0.302570  0.287137  0.279268
# ...        ...       ...       ...       ...       ...       ...       ...
# 9445  0.100609  0.105942  0.098262  0.097747  0.096864  0.093309  0.092230
# 9446  0.187324  0.189625  0.200367  0.207364  0.199058  0.188937  0.204206
# 9447  0.067231  0.069571  0.069697  0.065437  0.067554  0.067096  0.065376
# 9461  0.121746  0.124201  0.131800  0.136495  0.118695  0.130003  0.130447
# 9462  0.346430  0.357068  0.376196  0.382657  0.353937  0.371511  0.351670
# 9465  0.067231  0.069571  0.069697  0.065437  0.067554  0.067096  0.065376
# 9471  0.236158  0.244835  0.237106  0.209912  0.228311  0.222157  0.227291
# 9472  0.464751  0.457933  0.479748  0.469100  0.496620  0.467210  0.500890
# 9473  0.453126  0.460712  0.465042  0.465573  0.454139  0.448105  0.477514
# 9474  0.502090  0.503113  0.515308  0.493019  0.481008  0.503095  0.491364
# 9521  0.197332  0.191153  0.204845  0.209861  0.202123  0.192820  0.220680
# 9522  0.049138  0.051056  0.052951  0.047653  0.052078  0.045649  0.045163
# 9523  0.067231  0.069571  0.069697  0.065437  0.067554  0.067096  0.065376
# 9524  0.197332  0.191153  0.204845  0.209861  0.202123  0.192820  0.220680
# 9525  0.067231  0.069571  0.069697  0.065437  0.067554  0.067096  0.065376
# 9526  0.049138  0.051056  0.052951  0.047653  0.052078  0.045649  0.045163
# 9527  0.067231  0.069571  0.069697  0.065437  0.067554  0.067096  0.065376
# 9531  0.168508  0.163189  0.180023  0.181301  0.169248  0.168083  0.184872
# 9534  0.341172  0.383879  0.377985  0.370582  0.366391  0.374992  0.400179
# 9535  0.067231  0.069571  0.069697  0.065437  0.067554  0.067096  0.065376
# 9536  0.221061  0.212545  0.218708  0.216259  0.224063  0.202862  0.217630
# 9537  0.067231  0.069571  0.069697  0.065437  0.067554  0.067096  0.065376
# 9611  0.190913  0.189009  0.191573  0.190987  0.191193  0.189186  0.189078
# 9612  0.190913  0.189009  0.191573  0.190987  0.191193  0.189186  0.189078
# 9613  0.190913  0.189009  0.191573  0.190987  0.191193  0.189186  0.189078
# 9614  0.190913  0.189009  0.191573  0.190987  0.191193  0.189186  0.189078
# 9615  0.190913  0.189009  0.191573  0.190987  0.191193  0.189186  0.189078
# 9616  0.190913  0.189009  0.191573  0.190987  0.191193  0.189186  0.189078
# 9618  0.190913  0.189009  0.191573  0.190987  0.191193  0.189186  0.189078
# 9619  0.197332  0.191153  0.204845  0.209861  0.202123  0.192820  0.220680
#
#              7         8         9
# noc
# 12    0.293374  0.289004  0.291007
# 14    0.293374  0.289004  0.291007
# 15    0.400669  0.402783  0.423007
# 16    0.293374  0.289004  0.291007
# 112   0.259889  0.253918  0.265026
# 113   0.408168  0.397050  0.413680
# 114   0.486025  0.455519  0.474200
# 121   0.301703  0.304665  0.321210
# 122   0.223727  0.226096  0.226588
# 124   0.445737  0.427401  0.447971
# 125   0.528337  0.530336  0.532321
# 131   0.459070  0.478523  0.459847
# 132   0.534856  0.523423  0.522416
# 211   0.725930  0.719009  0.706882
# 212   0.391855  0.389332  0.382163
# 213   0.561979  0.556929  0.573932
# 311   0.571432  0.573659  0.580619
# 414   0.299354  0.279326  0.286797
# 421   0.378414  0.371579  0.392978
# 422   0.440395  0.454878  0.450265
# 423   0.460820  0.457878  0.461182
# 431   0.511832  0.511013  0.499850
# 432   0.629381  0.617428  0.624007
# 512   0.469894  0.474259  0.471861
# 513   0.277979  0.279181  0.284082
# 601   0.400361  0.391303  0.409999
# 621   0.305937  0.294382  0.288238
# 651   0.347638  0.350580  0.363058
# 711   0.305937  0.294382  0.288238
# 712   0.305937  0.294382  0.288238
# ...        ...       ...       ...
# 9445  0.091931  0.103353  0.094371
# 9446  0.193143  0.189688  0.174702
# 9447  0.066315  0.065605  0.066225
# 9461  0.122599  0.134267  0.116326
# 9462  0.359361  0.357662  0.362115
# 9465  0.066315  0.065605  0.066225
# 9471  0.248343  0.226666  0.222005
# 9472  0.487059  0.462213  0.494560
# 9473  0.463892  0.492714  0.451968
# 9474  0.487187  0.515831  0.511162
# 9521  0.198774  0.200666  0.186117
# 9522  0.053589  0.050889  0.049088
# 9523  0.066315  0.065605  0.066225
# 9524  0.198774  0.200666  0.186117
# 9525  0.066315  0.065605  0.066225
# 9526  0.053589  0.050889  0.049088
# 9527  0.066315  0.065605  0.066225
# 9531  0.174181  0.169581  0.161360
# 9534  0.369270  0.389584  0.361038
# 9535  0.066315  0.065605  0.066225
# 9536  0.210029  0.223102  0.206645
# 9537  0.066315  0.065605  0.066225
# 9611  0.189654  0.193450  0.188384
# 9612  0.189654  0.193450  0.188384
# 9613  0.189654  0.193450  0.188384
# 9614  0.189654  0.193450  0.188384
# 9615  0.189654  0.193450  0.188384
# 9616  0.189654  0.193450  0.188384
# 9618  0.189654  0.193450  0.188384
# 9619  0.198774  0.200666  0.186117
#
# [440 rows x 10 columns]

# %%
diffs = []

for i in range(10):
    for j in range(i+1,10):
            diffs.append(abs(robust_check[i]-robust_check[j]))

diffs = pd.DataFrame(diffs).T

# %%
diffs.mean(axis = 1).max()
# Out:
# 0.02812374222404774

# %%
diffs.mean(axis = 1).mean()
# Out:
# 0.012801559281807944

# %%
diffs.mean(axis = 1).std()
# Out:
# 0.006167376759758776

# %%
plt.hist(np.hstack(np.hstack(np.asarray(diffs)).shape))
plt.show()

# %%
rank_diffs = []

robust_check_ranks = robust_check.rank(axis=0)

for i in range(10):
    for j in range(i+1,10):
        rank_diffs.append(abs(robust_check_ranks[i]-robust_check_ranks[j]))

rank_diffs = pd.DataFrame(rank_diffs).T

# %%
rank_diffs.mean(axis=1).mean()
# Out:
# 10.284090909090907

# %%
rank_diffs.mean(axis=1).std()
# Out:
# 7.187448476777346

# %%
plt.hist(rank_diffs.mean(axis=1))
plt.title('Rank variation between runs for NOCs')
plt.xlabel('Mean Absolute Difference')
plt.ylabel('frequency')
plt.savefig('rank variation across runs')
plt.show()
