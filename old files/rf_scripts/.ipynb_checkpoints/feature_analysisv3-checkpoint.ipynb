# %%
def tree_paths(tree):
    
    children_left = tree.children_left
    children_right = tree.children_right
    values = tree.value
    
    tree_paths = []
    tree_probs = []
    path = []
    path_probs = []
    stack = [(0, -1)]  # seed is the root node id and its parent depth
    while len(stack) > 0:
        node_id, parent_depth = stack.pop()    
               
        while len(path)>parent_depth+1:
            path.pop()
            path_probs.pop()
        path.append(node_id)
        true = values[node_id][0][0].copy()
        false = values[node_id][0][1].copy()
        path_probs.append(round(true/(true+false),3))
        
        # If we have a test node
        if (children_left[node_id] != children_right[node_id]):
            stack.append((children_left[node_id], parent_depth + 1))
            stack.append((children_right[node_id], parent_depth + 1))
        else:
            tree_paths.append(path.copy())
            tree_probs.append(path_probs.copy())
            
    return tree_paths, tree_probs

# %%
def forest_paths(model):    
    forest_attributes = []
    baseline_means = []
    
    for treeEst in model.estimators_:
        path_thresholds = []
        path_features = []
        path_probs = []
        
        children_left = treeEst.tree_.children_left
        children_right = treeEst.tree_.children_right
        all_thresholds = treeEst.tree_.threshold
        all_features = treeEst.tree_.feature

        paths, path_probs = tree_paths(treeEst.tree_)
        
        leaf_probs = []
        for prob_list in path_probs:
                leaf_probs.append(prob_list[len(prob_list)-1])
        baseline_means.append(np.mean(leaf_probs))

        for i in range(len(paths)):
            thresholds = []
            features = []
            for j in range(len(paths[i])-1):
                if paths[i][j+1] == children_right[paths[i][j]]:
                    thresholds.append(all_thresholds[paths[i][j]])
                else:
                    thresholds.append(-all_thresholds[paths[i][j]])
                features.append(all_features[paths[i][j]])
            path_thresholds.append(thresholds.copy())
            path_features.append(features.copy())
    
        tree_atributes = pd.DataFrame([path_features, path_thresholds, path_probs]).T
        tree_atributes.columns = ['features','thresholds','path_probs']
        forest_attributes.append(tree_atributes.copy())
    return forest_attributes, np.mean(baseline_means)

# %%
def init_influence_list(features,conditionals,product):
    if product:
        combo_index = pd.MultiIndex.from_product([features,conditionals])
    else:
        combo_index = pd.MultiIndex.from_arrays([features,conditionals])
    
    infl_lists = []
    for i in range(combo_index.to_series().shape[0]):
        infl_lists.append([])
    
    influences = pd.Series(infl_lists,index=combo_index)
    
    return influences

# %%
def get_influences(feature_combos,model):
    forest_attributes, baseline = forest_paths(model)
    
    for tree_frame in forest_attributes:
        for index, path in tree_frame.iterrows():       
            for step in range(len(path['features'])-1):
                #what features we have seen and the feature we are on
                previous = np.append(path['features'][0:step],-1)
                current_feature = path['features'][step]
                if current_feature in feature_combos.index.get_level_values(0):
                    #make relevant calculations
                    current_prob = path['path_probs'][step]
                    next_prob = path['path_probs'][step+1]
                    pct_change = (next_prob-current_prob)/current_prob
                    influence = np.sign(path['thresholds'][step])*pct_change
                    #add to all relevant combos
                    for combo in feature_combos.loc[current_feature,previous]:
                        combo.append(influence)
                
    influences_df = pd.DataFrame(index=feature_combos.index)
    
    for index, influences in feature_combos.iteritems():
        if influences:
            influences = np.asarray(influences)
            influences_df.loc[index,'pos_influence'] = np.mean(influences[influences>0])
            influences_df.loc[index,'neg_influence'] = np.mean(influences[influences<=0])
            influences_df.loc[index,'pct_pos'] = np.sum(influences>0)/len(influences)
            influences_df.loc[index,'path count'] = len(influences)
    return influences_df

# %%
def feature_name_index(table):
    table_index = pd.MultiIndex.from_arrays([
        x.columns[table.index.get_level_values(0)],
        x.columns[table.index.get_level_values(1)]
    ])

    table.index = table_index
    
    return table

# %%
# %run utils_rf
from sklearn import tree

# %%
#read training data
file = "../../tables/noc_answers.csv"
x, x_agg, y, y_agg, x_noclvl, y_noclvl = data_proccess(file,True)
x.drop(['work_num_1','work_num_2','work_num_3','work_num_4','work_num_5','work_num_6'],axis=1,inplace=True)

#grab just the noc codes to cut out test nocs from main noc table
train_nocs = pd.read_csv(file,usecols=['noc_code']).drop_duplicates()

# %%
rf = RandomForestClassifier(**init_params('cat'))

rf.fit(x,y['increase'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=8, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=250, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
sffs_prob_features = ['value.Learning Strategies',
             'value.Monitoring',
             'value.Persuasion',
             'value.Service Orientation',
             'value.Management of Material Resources',
             'value.Information Ordering',
             'value.Memorization',
             'value.Flexibility of Closure',
             'value.Time Sharing',
             'value.Finger Dexterity',
             'value.Far Vision',
             'value.Computers and Electronics',
             'value.Chemistry',
             'value.Biology']

x_sffs = x.loc[:,sffs_prob_features]

# %%
rf_sffs = RandomForestClassifier(**init_params('cat'))
rf_sffs.fit(x_sffs,y['increase'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=8, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=250, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf_features = pd.Series(rf.feature_importances_,index=x.columns)
selected_features = rf_features.sort_values(ascending=False).iloc[0:20]
selected_features_ix = np.where(np.isin(x.columns,selected_features.index))[0]
selected_features = x.columns[selected_features_ix]

# %%
all_combos = init_influence_list(selected_features_ix,range(-1,120),True)
selected_combos = get_influences(all_combos,rf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
all_sffs_combos = init_influence_list(range(0,14),range(-1,120),True)
selected_sffs_combos = get_influences(all_sffs_combos,rf_sffs)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
selected_sffs_combos = feature_name_index(selected_sffs_combos)

# %%
all_independents = init_influence_list(range(0,120),[-1],True)
independent_influences = get_influences(all_independents,rf)

# %%
independent_influences = feature_name_index(independent_influences)

# %%
independent_influences.sort_values('pct_pos',ascending=False)
# Out:
#                                                              pos_influence  \
# value.Memorization                     value.Transportation       0.303741
# value.Fluency of Ideas                 value.Transportation       0.406025
# value.Systems Evaluation               value.Transportation       0.341401
# value.Instructing                      value.Transportation       0.319096
# value.Persuasion                       value.Transportation       0.379083
# value.Service Orientation              value.Transportation       0.298379
# value.Fine Arts                        value.Transportation       0.149403
# value.Originality                      value.Transportation       0.347700
# value.Number Facility                  value.Transportation       0.344997
# value.Technology Design                value.Transportation       0.185255
# value.Systems Analysis                 value.Transportation       0.322796
# value.Visualization                    value.Transportation       0.233314
# value.Philosophy and Theology          value.Transportation       0.199384
# value.Installation                     value.Transportation       0.125202
# value.Active Listening                 value.Transportation       0.241776
# value.History and Archeology           value.Transportation       0.284213
# value.Deductive Reasoning              value.Transportation       0.260218
# value.Customer and Personal Service    value.Transportation       0.242292
# value.Auditory Attention               value.Transportation       0.230557
# value.Chemistry                        value.Transportation       0.211151
# value.Equipment Selection              value.Transportation       0.243439
# value.Foreign Language                 value.Transportation       0.203562
# value.Psychology                       value.Transportation       0.213798
# value.Problem Sensitivity              value.Transportation       0.294915
# value.Arm-Hand Steadiness              value.Transportation       0.167210
# value.Dynamic Flexibility              value.Transportation       0.119249
# value.Management of Material Resources value.Transportation       0.145914
# value.Sociology and Anthropology       value.Transportation       0.174320
# value.Explosive Strength               value.Transportation       0.264111
# value.Design                           value.Transportation       0.226657
# ...                                                                    ...
# value.Physics                          value.Transportation       0.171947
# value.Night Vision                     value.Transportation       0.186509
# value.Written Expression               value.Transportation       0.214114
# value.Oral Expression                  value.Transportation       0.114022
# value.Mathematics Knowledge            value.Transportation       0.294577
# value.Near Vision                      value.Transportation       0.217645
# value.Coordination                     value.Transportation       0.321260
# value.Judgment and Decision Making     value.Transportation       0.207098
# value.Time Sharing                     value.Transportation       0.336945
# value.Reaction Time                    value.Transportation       0.203621
# value.Peripheral Vision                value.Transportation       0.293696
# value.Writing                          value.Transportation       0.120307
# value.Communications and Media         value.Transportation       0.150938
# value.Science                          value.Transportation       0.183361
# value.Economics and Accounting         value.Transportation       0.207621
# value.Sound Localization               value.Transportation       0.391251
# value.Transportation                   value.Transportation       0.212910
# value.Operation Monitoring             value.Transportation       0.213347
# value.Perceptual Speed                 value.Transportation       0.103566
# value.Control Precision                value.Transportation       0.184380
# value.Law and Government               value.Transportation       0.254239
# value.Gross Body Equilibrium           value.Transportation       0.206828
# value.Selective Attention              value.Transportation       0.093240
# value.Speaking                         value.Transportation       0.182451
# value.Category Flexibility             value.Transportation       0.132697
# value.Written Comprehension            value.Transportation       0.266603
# value.Monitoring                       value.Transportation       0.124170
# value.Flexibility of Closure           value.Transportation       0.170984
# value.Static Strength                  value.Transportation       0.277309
# value.Rate Control                     value.Transportation       0.145488
#
#                                                              neg_influence  \
# value.Memorization                     value.Transportation      -0.139704
# value.Fluency of Ideas                 value.Transportation      -0.128103
# value.Systems Evaluation               value.Transportation      -0.116726
# value.Instructing                      value.Transportation      -0.145940
# value.Persuasion                       value.Transportation      -0.153903
# value.Service Orientation              value.Transportation      -0.160304
# value.Fine Arts                        value.Transportation      -0.064652
# value.Originality                      value.Transportation      -0.156877
# value.Number Facility                  value.Transportation      -0.070851
# value.Technology Design                value.Transportation      -0.174036
# value.Systems Analysis                 value.Transportation      -0.169622
# value.Visualization                    value.Transportation      -0.370544
# value.Philosophy and Theology          value.Transportation      -0.077282
# value.Installation                     value.Transportation      -0.159470
# value.Active Listening                 value.Transportation      -0.103873
# value.History and Archeology           value.Transportation      -0.062249
# value.Deductive Reasoning              value.Transportation      -0.157230
# value.Customer and Personal Service    value.Transportation      -0.183510
# value.Auditory Attention               value.Transportation      -0.261111
# value.Chemistry                        value.Transportation      -0.174503
# value.Equipment Selection              value.Transportation      -0.134267
# value.Foreign Language                 value.Transportation      -0.171171
# value.Psychology                       value.Transportation      -0.177780
# value.Problem Sensitivity              value.Transportation      -0.218599
# value.Arm-Hand Steadiness              value.Transportation      -0.242259
# value.Dynamic Flexibility              value.Transportation      -0.063258
# value.Management of Material Resources value.Transportation      -0.131423
# value.Sociology and Anthropology       value.Transportation      -0.088836
# value.Explosive Strength               value.Transportation      -0.193280
# value.Design                           value.Transportation      -0.234639
# ...                                                                    ...
# value.Physics                          value.Transportation      -0.183946
# value.Night Vision                     value.Transportation      -0.235379
# value.Written Expression               value.Transportation      -0.254392
# value.Oral Expression                  value.Transportation      -0.142416
# value.Mathematics Knowledge            value.Transportation      -0.103516
# value.Near Vision                      value.Transportation      -0.337811
# value.Coordination                     value.Transportation      -0.209727
# value.Judgment and Decision Making     value.Transportation      -0.282783
# value.Time Sharing                     value.Transportation      -0.162720
# value.Reaction Time                    value.Transportation      -0.235336
# value.Peripheral Vision                value.Transportation      -0.149710
# value.Writing                          value.Transportation      -0.299690
# value.Communications and Media         value.Transportation      -0.305973
# value.Science                          value.Transportation      -0.436536
# value.Economics and Accounting         value.Transportation      -0.240915
# value.Sound Localization               value.Transportation      -0.179645
# value.Transportation                   value.Transportation      -0.187398
# value.Operation Monitoring             value.Transportation      -0.208189
# value.Perceptual Speed                 value.Transportation      -0.208584
# value.Control Precision                value.Transportation      -0.205206
# value.Law and Government               value.Transportation      -0.194558
# value.Gross Body Equilibrium           value.Transportation      -0.151860
# value.Selective Attention              value.Transportation      -0.059441
# value.Speaking                         value.Transportation      -0.166763
# value.Category Flexibility             value.Transportation      -0.275740
# value.Written Comprehension            value.Transportation      -0.141228
# value.Monitoring                       value.Transportation      -0.201436
# value.Flexibility of Closure           value.Transportation      -0.305778
# value.Static Strength                  value.Transportation      -0.239311
# value.Rate Control                     value.Transportation      -0.232858
#
#                                                               pct_pos  \
# value.Memorization                     value.Transportation  0.989091
# value.Fluency of Ideas                 value.Transportation  0.980210
# value.Systems Evaluation               value.Transportation  0.970628
# value.Instructing                      value.Transportation  0.962264
# value.Persuasion                       value.Transportation  0.961930
# value.Service Orientation              value.Transportation  0.960057
# value.Fine Arts                        value.Transportation  0.959016
# value.Originality                      value.Transportation  0.956120
# value.Number Facility                  value.Transportation  0.948421
# value.Technology Design                value.Transportation  0.942718
# value.Systems Analysis                 value.Transportation  0.939141
# value.Visualization                    value.Transportation  0.930876
# value.Philosophy and Theology          value.Transportation  0.928105
# value.Installation                     value.Transportation  0.924188
# value.Active Listening                 value.Transportation  0.907051
# value.History and Archeology           value.Transportation  0.905237
# value.Deductive Reasoning              value.Transportation  0.889313
# value.Customer and Personal Service    value.Transportation  0.887463
# value.Auditory Attention               value.Transportation  0.858934
# value.Chemistry                        value.Transportation  0.839080
# value.Equipment Selection              value.Transportation  0.838765
# value.Foreign Language                 value.Transportation  0.834764
# value.Psychology                       value.Transportation  0.829528
# value.Problem Sensitivity              value.Transportation  0.828442
# value.Arm-Hand Steadiness              value.Transportation  0.827534
# value.Dynamic Flexibility              value.Transportation  0.815668
# value.Management of Material Resources value.Transportation  0.813793
# value.Sociology and Anthropology       value.Transportation  0.813462
# value.Explosive Strength               value.Transportation  0.800000
# value.Design                           value.Transportation  0.798472
# ...                                                               ...
# value.Physics                          value.Transportation  0.325758
# value.Night Vision                     value.Transportation  0.294872
# value.Written Expression               value.Transportation  0.292308
# value.Oral Expression                  value.Transportation  0.285714
# value.Mathematics Knowledge            value.Transportation  0.276176
# value.Near Vision                      value.Transportation  0.242494
# value.Coordination                     value.Transportation  0.237179
# value.Judgment and Decision Making     value.Transportation  0.234114
# value.Time Sharing                     value.Transportation  0.233096
# value.Reaction Time                    value.Transportation  0.232558
# value.Peripheral Vision                value.Transportation  0.214724
# value.Writing                          value.Transportation  0.214123
# value.Communications and Media         value.Transportation  0.207364
# value.Science                          value.Transportation  0.190476
# value.Economics and Accounting         value.Transportation  0.188725
# value.Sound Localization               value.Transportation  0.178571
# value.Transportation                   value.Transportation  0.166795
# value.Operation Monitoring             value.Transportation  0.161880
# value.Perceptual Speed                 value.Transportation  0.156489
# value.Control Precision                value.Transportation  0.154696
# value.Law and Government               value.Transportation  0.149390
# value.Gross Body Equilibrium           value.Transportation  0.145199
# value.Selective Attention              value.Transportation  0.142857
# value.Speaking                         value.Transportation  0.135593
# value.Category Flexibility             value.Transportation  0.127517
# value.Written Comprehension            value.Transportation  0.123839
# value.Monitoring                       value.Transportation  0.095495
# value.Flexibility of Closure           value.Transportation  0.085616
# value.Static Strength                  value.Transportation  0.082569
# value.Rate Control                     value.Transportation  0.049828
#
#                                                              path count
# value.Memorization                     value.Transportation      1375.0
# value.Fluency of Ideas                 value.Transportation      1617.0
# value.Systems Evaluation               value.Transportation      1464.0
# value.Instructing                      value.Transportation       901.0
# value.Persuasion                       value.Transportation      1865.0
# value.Service Orientation              value.Transportation      1402.0
# value.Fine Arts                        value.Transportation       366.0
# value.Originality                      value.Transportation      1299.0
# value.Number Facility                  value.Transportation       950.0
# value.Technology Design                value.Transportation      1030.0
# value.Systems Analysis                 value.Transportation       838.0
# value.Visualization                    value.Transportation       868.0
# value.Philosophy and Theology          value.Transportation       459.0
# value.Installation                     value.Transportation       277.0
# value.Active Listening                 value.Transportation       312.0
# value.History and Archeology           value.Transportation       401.0
# value.Deductive Reasoning              value.Transportation       262.0
# value.Customer and Personal Service    value.Transportation      1013.0
# value.Auditory Attention               value.Transportation       638.0
# value.Chemistry                        value.Transportation       783.0
# value.Equipment Selection              value.Transportation       583.0
# value.Foreign Language                 value.Transportation       466.0
# value.Psychology                       value.Transportation       657.0
# value.Problem Sensitivity              value.Transportation       443.0
# value.Arm-Hand Steadiness              value.Transportation       661.0
# value.Dynamic Flexibility              value.Transportation       217.0
# value.Management of Material Resources value.Transportation       290.0
# value.Sociology and Anthropology       value.Transportation       520.0
# value.Explosive Strength               value.Transportation       455.0
# value.Design                           value.Transportation      1047.0
# ...                                                                 ...
# value.Physics                          value.Transportation       264.0
# value.Night Vision                     value.Transportation       156.0
# value.Written Expression               value.Transportation       325.0
# value.Oral Expression                  value.Transportation        84.0
# value.Mathematics Knowledge            value.Transportation       659.0
# value.Near Vision                      value.Transportation       433.0
# value.Coordination                     value.Transportation       312.0
# value.Judgment and Decision Making     value.Transportation       299.0
# value.Time Sharing                     value.Transportation       562.0
# value.Reaction Time                    value.Transportation       946.0
# value.Peripheral Vision                value.Transportation       163.0
# value.Writing                          value.Transportation       439.0
# value.Communications and Media         value.Transportation       516.0
# value.Science                          value.Transportation       840.0
# value.Economics and Accounting         value.Transportation       408.0
# value.Sound Localization               value.Transportation       224.0
# value.Transportation                   value.Transportation      1295.0
# value.Operation Monitoring             value.Transportation       383.0
# value.Perceptual Speed                 value.Transportation       262.0
# value.Control Precision                value.Transportation       543.0
# value.Law and Government               value.Transportation       984.0
# value.Gross Body Equilibrium           value.Transportation       427.0
# value.Selective Attention              value.Transportation        28.0
# value.Speaking                         value.Transportation       236.0
# value.Category Flexibility             value.Transportation       298.0
# value.Written Comprehension            value.Transportation       323.0
# value.Monitoring                       value.Transportation       555.0
# value.Flexibility of Closure           value.Transportation       292.0
# value.Static Strength                  value.Transportation       763.0
# value.Rate Control                     value.Transportation       582.0
#
# [120 rows x 4 columns]

# %%
pd.DataFrame({
    'pct pos':
        selected_combos['pct_pos'][selected_combos['path count']>200][:,'value.Transportation'],
    'Pos Influence':
        selected_combos['pos_influence'][selected_combos['path count']>200][:,'value.Transportation'],
    'Neg Influence':
        selected_combos['neg_influence'][selected_combos['path count']>200][:,'value.Transportation']
}).sort_values('pct pos',ascending=False)
# Out:
#                                       pct pos  Pos Influence  Neg Influence
# value.Memorization                   0.989091       0.303741      -0.139704
# value.Fluency of Ideas               0.980210       0.406025      -0.128103
# value.Systems Evaluation             0.970628       0.341401      -0.116726
# value.Instructing                    0.962264       0.319096      -0.145940
# value.Persuasion                     0.961930       0.379083      -0.153903
# value.Service Orientation            0.960057       0.298379      -0.160304
# value.Originality                    0.956120       0.347700      -0.156877
# value.Number Facility                0.948421       0.344997      -0.070851
# value.Technology Design              0.942718       0.185255      -0.174036
# value.Systems Analysis               0.939141       0.322796      -0.169622
# value.Visualization                  0.930876       0.233314      -0.370544
# value.Customer and Personal Service  0.887463       0.242292      -0.183510
# value.Chemistry                      0.839080       0.211151      -0.174503
# value.Design                         0.798472       0.226657      -0.234639
# value.Computers and Electronics      0.739387       0.230394      -0.431494
# value.Negotiation                    0.406297       0.321878      -0.180066
# value.Reaction Time                  0.232558       0.203621      -0.235336
# value.Transportation                 0.166795       0.212910      -0.187398
# value.Law and Government             0.149390       0.254239      -0.194558
# value.Static Strength                0.082569       0.277309      -0.239311

# %%
pd.DataFrame({
    'pct pos':
        selected_sffs_combos['pct_pos'][selected_sffs_combos['path count']>200][:,'value.Transportation'],
    'Pos Influence':
        selected_sffs_combos['pos_influence'][selected_sffs_combos['path count']>200][:,'value.Transportation'],
    'Neg Influence':
        selected_sffs_combos['neg_influence'][selected_sffs_combos['path count']>200][:,'value.Transportation']
}).sort_values('pct pos',ascending=False)
# Out:
#                               pct pos  Pos Influence  Neg Influence
# value.Critical Thinking      0.970207       0.291593      -0.101478
# value.Writing                0.922587       0.339570      -0.101230
# value.Speaking               0.910930       0.282302      -0.154833
# value.Mathematics Skill      0.867931       0.105588      -0.056547
# value.Reading Comprehension  0.799568       0.224773      -0.151341
# value.Coordination           0.725109       0.226631      -0.430163
# value.Monitoring             0.707041       0.167189      -0.188349
# value.Persuasion             0.700778       0.217126      -0.164128
# value.Social Perceptiveness  0.699394       0.169688      -0.076319
# value.Science                0.560571       0.193423      -0.131132
# value.Negotiation            0.495798       0.129127      -0.202702
# value.Learning Strategies    0.418471       0.240409      -0.162750
# value.Active Learning        0.134276       0.127617      -0.230342
# value.Active Listening       0.130666       0.157570      -0.190348

# %% [markdown]
# Non Structural Sufficiency Test
