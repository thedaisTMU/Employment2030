# %%
import pickle
# %run utils_rf

# %%
with open('log_loss_results.pkl','rb') as f:
    log_loss_results = pickle.load(f)

# %%
with open('mae_results.pkl','rb') as f:
    mae_results = pickle.load(f)

# %%
log_loss_results
# Out:
# [{1: {'feature_idx': (48,),
#    'cv_scores': array([-0.62973807, -0.50770141, -0.8003066 , -0.58484529, -0.52391818]),
#    'avg_score': -0.6093019103658224,
#    'feature_names': ('value.Memorization',),
#    'ci_bound': 0.13493913685209802,
#    'std_dev': 0.10498723279691621,
#    'std_err': 0.0524936163984581},
#   2: {'feature_idx': (48, 58),
#    'cv_scores': array([-0.60807777, -0.47957998, -0.70887583, -0.58652446, -0.54511408]),
#    'avg_score': -0.5856344276469382,
#    'feature_names': ('value.Memorization', 'value.Finger Dexterity'),
#    'ci_bound': 0.09717748543897661,
#    'std_dev': 0.07560738511009785,
#    'std_err': 0.03780369255504892},
#   3: {'feature_idx': (48, 58, 80),
#    'cv_scores': array([-0.55560651, -0.50696587, -0.68966626, -0.59277114, -0.51356479]),
#    'avg_score': -0.5717149148928767,
#    'feature_names': ('value.Memorization',
#     'value.Finger Dexterity',
#     'value.Depth Perception'),
#    'ci_bound': 0.08562245313814855,
#    'std_dev': 0.06661717741762838,
#    'std_err': 0.03330858870881419},
#   4: {'feature_idx': (48, 58, 64, 80),
#    'cv_scores': array([-0.54605322, -0.48535352, -0.7133598 , -0.58863737, -0.51982944]),
#    'avg_score': -0.5706466717508736,
#    'feature_names': ('value.Memorization',
#     'value.Finger Dexterity',
#     'value.Wrist-Finger Speed',
#     'value.Depth Perception'),
#    'ci_bound': 0.10145310611161441,
#    'std_dev': 0.078933963250297,
#    'std_err': 0.0394669816251485},
#   5: {'feature_idx': (48, 58, 64, 78, 80),
#    'cv_scores': array([-0.54763178, -0.48810874, -0.70916743, -0.59313852, -0.51650902]),
#    'avg_score': -0.5709110963764438,
#    'feature_names': ('value.Memorization',
#     'value.Finger Dexterity',
#     'value.Wrist-Finger Speed',
#     'value.Night Vision',
#     'value.Depth Perception'),
#    'ci_bound': 0.09950279694461688,
#    'std_dev': 0.07741655645996043,
#    'std_err': 0.038708278229980214},
#   6: {'feature_idx': (48, 58, 59, 64, 78, 80),
#    'cv_scores': array([-0.55394874, -0.47696966, -0.71821998, -0.58156249, -0.5378831 ]),
#    'avg_score': -0.5737167933673278,
#    'feature_names': ('value.Memorization',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Wrist-Finger Speed',
#     'value.Night Vision',
#     'value.Depth Perception'),
#    'ci_bound': 0.10278721696005758,
#    'std_dev': 0.07997194681451614,
#    'std_err': 0.03998597340725807},
#   7: {'feature_idx': (48, 51, 58, 59, 78, 79, 80),
#    'cv_scores': array([-0.5684944 , -0.47325278, -0.72228108, -0.58684649, -0.53985745]),
#    'avg_score': -0.5781464398055236,
#    'feature_names': ('value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception'),
#    'ci_bound': 0.10506791433996313,
#    'std_dev': 0.08174640685886864,
#    'std_err': 0.04087320342943431},
#   8: {'feature_idx': (48, 51, 58, 59, 76, 78, 79, 80),
#    'cv_scores': array([-0.58026701, -0.46523407, -0.72667408, -0.58741348, -0.51209253]),
#    'avg_score': -0.574336233478561,
#    'feature_names': ('value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Far Vision',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception'),
#    'ci_bound': 0.11379082149299863,
#    'std_dev': 0.08853312496975585,
#    'std_err': 0.044266562484877925},
#   9: {'feature_idx': (48, 51, 58, 59, 76, 78, 80, 118, 119),
#    'cv_scores': array([-0.57552208, -0.46604186, -0.71654895, -0.56218568, -0.47902827]),
#    'avg_score': -0.5598653683558606,
#    'feature_names': ('value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Far Vision',
#     'value.Night Vision',
#     'value.Depth Perception',
#     'value.Communications and Media',
#     'value.Transportation'),
#    'ci_bound': 0.11515768989449124,
#    'std_dev': 0.08959659502312921,
#    'std_err': 0.0447982975115646},
#   10: {'feature_idx': (48, 51, 58, 59, 76, 78, 80, 84, 118, 119),
#    'cv_scores': array([-0.57119738, -0.4651174 , -0.71740486, -0.56542861, -0.48055429]),
#    'avg_score': -0.5599405078531251,
#    'feature_names': ('value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Far Vision',
#     'value.Night Vision',
#     'value.Depth Perception',
#     'value.Sound Localization',
#     'value.Communications and Media',
#     'value.Transportation'),
#    'ci_bound': 0.11531209028622318,
#    'std_dev': 0.08971672377338542,
#    'std_err': 0.04485836188669271},
#   11: {'feature_idx': (48, 51, 58, 59, 76, 78, 79, 80, 84, 118, 119),
#    'cv_scores': array([-0.56664586, -0.46639831, -0.71525912, -0.57260751, -0.47961859]),
#    'avg_score': -0.5601058776745668,
#    'feature_names': ('value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Far Vision',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Sound Localization',
#     'value.Communications and Media',
#     'value.Transportation'),
#    'ci_bound': 0.11428383472946035,
#    'std_dev': 0.0889167060170031,
#    'std_err': 0.04445835300850155},
#   12: {'feature_idx': (46, 48, 51, 58, 59, 76, 78, 79, 80, 84, 118, 119),
#    'cv_scores': array([-0.57512365, -0.46544301, -0.70773216, -0.55513679, -0.49718263]),
#    'avg_score': -0.5601236490242858,
#    'feature_names': ('value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Far Vision',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Sound Localization',
#     'value.Communications and Media',
#     'value.Transportation'),
#    'ci_bound': 0.10748004715050151,
#    'std_dev': 0.08362312813354703,
#    'std_err': 0.04181156406677351},
#   13: {'feature_idx': (20, 46, 48, 51, 58, 61, 72, 76, 78, 79, 80, 84, 119),
#    'cv_scores': array([-0.56833149, -0.46285732, -0.6813408 , -0.58454997, -0.48614995]),
#    'avg_score': -0.556645908534952,
#    'feature_names': ('value.Installation',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.09993909444490154,
#    'std_dev': 0.07775601073764196,
#    'std_err': 0.03887800536882098},
#   14: {'feature_idx': (20,
#     21,
#     24,
#     46,
#     48,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     119),
#    'cv_scores': array([-0.56195805, -0.47953635, -0.68019427, -0.55946621, -0.48441059]),
#    'avg_score': -0.5531130912703082,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.09339704427353158,
#    'std_dev': 0.07266607344937002,
#    'std_err': 0.03633303672468501},
#   15: {'feature_idx': (20,
#     21,
#     24,
#     46,
#     48,
#     50,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     119),
#    'cv_scores': array([-0.5622713 , -0.48036498, -0.68188111, -0.55771198, -0.48794888]),
#    'avg_score': -0.5540356518159711,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.0930760661661198,
#    'std_dev': 0.07241634157712239,
#    'std_err': 0.03620817078856119},
#   16: {'feature_idx': (20,
#     21,
#     24,
#     46,
#     48,
#     50,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     84,
#     119),
#    'cv_scores': array([-0.56380956, -0.4796437 , -0.68339953, -0.5618231 , -0.4924523 ]),
#    'avg_score': -0.5562256379511485,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.09302857113797741,
#    'std_dev': 0.07237938883166542,
#    'std_err': 0.0361896944158327},
#   17: {'feature_idx': (20,
#     21,
#     24,
#     26,
#     33,
#     46,
#     48,
#     50,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     80,
#     84,
#     119),
#    'cv_scores': array([-0.56586621, -0.48059777, -0.68765666, -0.5608854 , -0.49367222]),
#    'avg_score': -0.5577356524071335,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Depth Perception',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.09446647241293078,
#    'std_dev': 0.0734981248738114,
#    'std_err': 0.0367490624369057},
#   18: {'feature_idx': (20,
#     21,
#     24,
#     33,
#     46,
#     48,
#     50,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     82,
#     84,
#     119),
#    'cv_scores': array([-0.5655651 , -0.48218698, -0.68913313, -0.56192348, -0.49616677]),
#    'avg_score': -0.5589950936572194,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.09415935237119462,
#    'std_dev': 0.07325917504746343,
#    'std_err': 0.036629587523731716},
#   19: {'feature_idx': (20,
#     21,
#     24,
#     26,
#     33,
#     46,
#     48,
#     50,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     119),
#    'cv_scores': array([-0.56884622, -0.48437693, -0.68687086, -0.56267766, -0.50488838]),
#    'avg_score': -0.56153200934055,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.09074926587420588,
#    'std_dev': 0.07060601190095996,
#    'std_err': 0.03530300595047997},
#   20: {'feature_idx': (20,
#     21,
#     24,
#     26,
#     33,
#     46,
#     48,
#     50,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     119),
#    'cv_scores': array([-0.56617565, -0.48130906, -0.69092229, -0.56241813, -0.51355732]),
#    'avg_score': -0.5628764916459588,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.09177453960094324,
#    'std_dev': 0.07140370969227988,
#    'std_err': 0.03570185484613994},
#   21: {'feature_idx': (20,
#     21,
#     24,
#     26,
#     33,
#     46,
#     48,
#     50,
#     51,
#     58,
#     61,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     119),
#    'cv_scores': array([-0.56386799, -0.48305089, -0.68984084, -0.56345413, -0.51666292]),
#    'avg_score': -0.5633753541176258,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.09020479219464338,
#    'std_dev': 0.0701823928806999,
#    'std_err': 0.03509119644034995},
#   22: {'feature_idx': (18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     46,
#     48,
#     50,
#     51,
#     58,
#     61,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     119),
#    'cv_scores': array([-0.56656745, -0.49842353, -0.68427514, -0.5587505 , -0.52491629]),
#    'avg_score': -0.5665865821513507,
#    'feature_names': ('value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.0818854728103566,
#    'std_dev': 0.06370967976510215,
#    'std_err': 0.03185483988255108},
#   23: {'feature_idx': (18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     46,
#     48,
#     50,
#     51,
#     58,
#     61,
#     62,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     119),
#    'cv_scores': array([-0.56383854, -0.50444715, -0.68334959, -0.55925475, -0.5261167 ]),
#    'avg_score': -0.5674013461756608,
#    'feature_names': ('value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Rate Control',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.0796272922367406,
#    'std_dev': 0.06195273856101285,
#    'std_err': 0.030976369280506424},
#   24: {'feature_idx': (18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     38,
#     46,
#     48,
#     50,
#     51,
#     58,
#     61,
#     62,
#     72,
#     75,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     119),
#    'cv_scores': array([-0.56906339, -0.49336668, -0.68040495, -0.56996371, -0.52790239]),
#    'avg_score': -0.5681402248974124,
#    'feature_names': ('value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Written Expression',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Rate Control',
#     'value.Dynamic Flexibility',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.08091763627846091,
#    'std_dev': 0.06295667006269932,
#    'std_err': 0.03147833503134966},
#   25: {'feature_idx': (18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     38,
#     46,
#     48,
#     50,
#     51,
#     52,
#     58,
#     61,
#     62,
#     72,
#     75,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     119),
#    'cv_scores': array([-0.57118148, -0.49993641, -0.68331083, -0.57005172, -0.52924933]),
#    'avg_score': -0.5707459563587749,
#    'feature_names': ('value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Written Expression',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Rate Control',
#     'value.Dynamic Flexibility',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.0800757580501005,
#    'std_dev': 0.062301660199664516,
#    'std_err': 0.031150830099832254},
#   26: {'feature_idx': (9,
#     18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     35,
#     46,
#     48,
#     50,
#     51,
#     52,
#     58,
#     61,
#     62,
#     72,
#     75,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     119),
#    'cv_scores': array([-0.5646259 , -0.49837415, -0.68189028, -0.57184367, -0.52876443]),
#    'avg_score': -0.569099687123256,
#    'feature_names': ('value.Monitoring',
#     'value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Oral Comprehension',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Rate Control',
#     'value.Dynamic Flexibility',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.08001551755532675,
#    'std_dev': 0.06225479104816293,
#    'std_err': 0.031127395524081464},
#   27: {'feature_idx': (9,
#     18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     35,
#     46,
#     48,
#     50,
#     51,
#     52,
#     58,
#     59,
#     61,
#     62,
#     72,
#     75,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     119),
#    'cv_scores': array([-0.56430297, -0.49754199, -0.68662773, -0.57434082, -0.53212987]),
#    'avg_score': -0.5709886775902897,
#    'feature_names': ('value.Monitoring',
#     'value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Oral Comprehension',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Response Orientation',
#     'value.Rate Control',
#     'value.Dynamic Flexibility',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.08196236520032874,
#    'std_dev': 0.06376950465678768,
#    'std_err': 0.03188475232839384},
#   28: {'feature_idx': (9,
#     18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     35,
#     46,
#     48,
#     50,
#     51,
#     52,
#     58,
#     59,
#     61,
#     62,
#     72,
#     75,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     119),
#    'cv_scores': array([-0.56513189, -0.50212405, -0.69115831, -0.57229233, -0.53404336]),
#    'avg_score': -0.5729499884833991,
#    'feature_names': ('value.Monitoring',
#     'value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Oral Comprehension',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Response Orientation',
#     'value.Rate Control',
#     'value.Dynamic Flexibility',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.0824287484585343,
#    'std_dev': 0.06413236667624378,
#    'std_err': 0.03206618333812188},
#   29: {'feature_idx': (9,
#     18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     35,
#     46,
#     48,
#     49,
#     50,
#     51,
#     52,
#     58,
#     59,
#     61,
#     62,
#     72,
#     75,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     119),
#    'cv_scores': array([-0.56279275, -0.5027678 , -0.69002263, -0.58183491, -0.5407246 ]),
#    'avg_score': -0.5756285370885188,
#    'feature_names': ('value.Monitoring',
#     'value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Oral Comprehension',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Speed of Closure',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Response Orientation',
#     'value.Rate Control',
#     'value.Dynamic Flexibility',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.08091466816771158,
#    'std_dev': 0.06295436077169987,
#    'std_err': 0.031477180385849936},
#   30: {'feature_idx': (9,
#     18,
#     20,
#     21,
#     24,
#     26,
#     33,
#     35,
#     43,
#     46,
#     48,
#     49,
#     50,
#     51,
#     52,
#     58,
#     59,
#     61,
#     62,
#     72,
#     75,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     119),
#    'cv_scores': array([-0.5667923 , -0.502629  , -0.6870044 , -0.58283211, -0.54728843]),
#    'avg_score': -0.5773092474690609,
#    'feature_names': ('value.Monitoring',
#     'value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Oral Comprehension',
#     'value.Inductive Reasoning',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Speed of Closure',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Response Orientation',
#     'value.Rate Control',
#     'value.Dynamic Flexibility',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Transportation'),
#    'ci_bound': 0.0785028157311638,
#    'std_dev': 0.061077857637511376,
#    'std_err': 0.030538928818755688}},
#  {1: {'feature_idx': (48,),
#    'cv_scores': array([-0.62919437, -0.50739604, -0.80058564, -0.58491091, -0.52422153]),
#    'avg_score': -0.6092616968010779,
#    'feature_names': ('value.Memorization',),
#    'ci_bound': 0.13505168287834587,
#    'std_dev': 0.10507479742889544,
#    'std_err': 0.05253739871444772},
#   2: {'feature_idx': (48, 58),
#    'cv_scores': array([-0.60761062, -0.47952857, -0.71054026, -0.58659858, -0.54487052]),
#    'avg_score': -0.5858297094687861,
#    'feature_names': ('value.Memorization', 'value.Finger Dexterity'),
#    'ci_bound': 0.09789379891723322,
#    'std_dev': 0.07616470133170467,
#    'std_err': 0.038082350665852326},
#   3: {'feature_idx': (48, 58, 80),
#    'cv_scores': array([-0.55578557, -0.50742034, -0.68782972, -0.59307771, -0.51262983]),
#    'avg_score': -0.5713486342681849,
#    'feature_names': ('value.Memorization',
#     'value.Finger Dexterity',
#     'value.Depth Perception'),
#    'ci_bound': 0.08490108842258937,
#    'std_dev': 0.06605593116179304,
#    'std_err': 0.03302796558089652},
#   4: {'feature_idx': (48, 58, 64, 80),
#    'cv_scores': array([-0.54433187, -0.48527544, -0.71591425, -0.58863392, -0.5201345 ]),
#    'avg_score': -0.5708579962581158,
#    'feature_names': ('value.Memorization',
#     'value.Finger Dexterity',
#     'value.Wrist-Finger Speed',
#     'value.Depth Perception'),
#    'ci_bound': 0.10275606553380592,
#    'std_dev': 0.07994770994657602,
#    'std_err': 0.03997385497328801},
#   5: {'feature_idx': (48, 58, 61, 80, 119),
#    'cv_scores': array([-0.57259156, -0.46704568, -0.71766682, -0.58820552, -0.48792369]),
#    'avg_score': -0.5666866533454988,
#    'feature_names': ('value.Memorization',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.11413045768830538,
#    'std_dev': 0.08879737346826236,
#    'std_err': 0.04439868673413117},
#   6: {'feature_idx': (43, 48, 58, 61, 80, 119),
#    'cv_scores': array([-0.57958177, -0.48393183, -0.7132665 , -0.55935611, -0.4850886 ]),
#    'avg_score': -0.5642449628368054,
#    'feature_names': ('value.Inductive Reasoning',
#     'value.Memorization',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.10781509335725535,
#    'std_dev': 0.08388380546502236,
#    'std_err': 0.04194190273251118},
#   7: {'feature_idx': (9, 43, 48, 58, 61, 80, 119),
#    'cv_scores': array([-0.56988247, -0.47155647, -0.69742618, -0.54983176, -0.48199111]),
#    'avg_score': -0.5541375963627738,
#    'feature_names': ('value.Monitoring',
#     'value.Inductive Reasoning',
#     'value.Memorization',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.1041368320114867,
#    'std_dev': 0.08102199317538708,
#    'std_err': 0.04051099658769354},
#   8: {'feature_idx': (9, 42, 43, 48, 58, 61, 80, 119),
#    'cv_scores': array([-0.57089165, -0.47987464, -0.70374694, -0.55007624, -0.48455614]),
#    'avg_score': -0.5578291219239779,
#    'feature_names': ('value.Monitoring',
#     'value.Deductive Reasoning',
#     'value.Inductive Reasoning',
#     'value.Memorization',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.10436780196175638,
#    'std_dev': 0.08120169564350521,
#    'std_err': 0.04060084782175261},
#   9: {'feature_idx': (9, 42, 43, 48, 58, 61, 77, 80, 119),
#    'cv_scores': array([-0.59641614, -0.48120341, -0.69344728, -0.55254152, -0.47661057]),
#    'avg_score': -0.560043785850943,
#    'feature_names': ('value.Monitoring',
#     'value.Deductive Reasoning',
#     'value.Inductive Reasoning',
#     'value.Memorization',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Visual Color Discrimination',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.10338826279484073,
#    'std_dev': 0.08043958089347991,
#    'std_err': 0.04021979044673995},
#   10: {'feature_idx': (9, 43, 48, 51, 58, 61, 77, 80, 98, 119),
#    'cv_scores': array([-0.57099605, -0.4714619 , -0.71604466, -0.55035143, -0.47787326]),
#    'avg_score': -0.5573454616412845,
#    'feature_names': ('value.Monitoring',
#     'value.Inductive Reasoning',
#     'value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Visual Color Discrimination',
#     'value.Depth Perception',
#     'value.Building and Construction',
#     'value.Transportation'),
#    'ci_bound': 0.11367743636430547,
#    'std_dev': 0.08844490748756709,
#    'std_err': 0.044222453743783544},
#   11: {'feature_idx': (9, 43, 48, 51, 58, 61, 72, 77, 80, 98, 119),
#    'cv_scores': array([-0.57860452, -0.47129364, -0.71907856, -0.55056619, -0.47715654]),
#    'avg_score': -0.5593398888143628,
#    'feature_names': ('value.Monitoring',
#     'value.Inductive Reasoning',
#     'value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Dynamic Flexibility',
#     'value.Visual Color Discrimination',
#     'value.Depth Perception',
#     'value.Building and Construction',
#     'value.Transportation'),
#    'ci_bound': 0.11563446144815996,
#    'std_dev': 0.08996753948938015,
#    'std_err': 0.04498376974469007},
#   12: {'feature_idx': (24, 46, 48, 51, 58, 72, 76, 77, 78, 80, 98, 119),
#    'cv_scores': array([-0.56219463, -0.48174422, -0.70839082, -0.55887298, -0.47277384]),
#    'avg_score': -0.5567952946690691,
#    'feature_names': ('value.Equipment Maintenance',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Depth Perception',
#     'value.Building and Construction',
#     'value.Transportation'),
#    'ci_bound': 0.1086157387488264,
#    'std_dev': 0.08450673478022007,
#    'std_err': 0.042253367390110035},
#   13: {'feature_idx': (24, 46, 48, 51, 58, 72, 76, 77, 78, 79, 80, 98, 119),
#    'cv_scores': array([-0.5573631 , -0.48264532, -0.70580341, -0.56171064, -0.47364808]),
#    'avg_score': -0.5562341113636672,
#    'feature_names': ('value.Equipment Maintenance',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Building and Construction',
#     'value.Transportation'),
#    'ci_bound': 0.10697760527606291,
#    'std_dev': 0.08323221128563195,
#    'std_err': 0.041616105642815975},
#   14: {'feature_idx': (20,
#     21,
#     24,
#     46,
#     48,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     119),
#    'cv_scores': array([-0.56138217, -0.47712072, -0.68217784, -0.55914223, -0.48384298]),
#    'avg_score': -0.5527331872796892,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.09503317134064997,
#    'std_dev': 0.07393903589220206,
#    'std_err': 0.03696951794610103},
#   15: {'feature_idx': (20,
#     21,
#     24,
#     46,
#     48,
#     50,
#     51,
#     58,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     119),
#    'cv_scores': array([-0.56325153, -0.47921362, -0.67682935, -0.55794301, -0.48892287]),
#    'avg_score': -0.5532320749255096,
#    'feature_names': ('value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Dynamic Flexibility',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Transportation'),
#    'ci_bound': 0.09090791512511859,
#    'std_dev': 0.07072944640800652,
#    'std_err': 0.03536472320400326},
#   16: {'feature_idx': (20,
#     24,
#     26,
#     46,
#     48,
#     50,
#     51,
#     58,
#     76,
#     77,
#     78,
#     82,
#     84,
#     102,
#     103,
#     119),
#    'cv_scores': array([-0.53632051, -0.46080041, -0.66724271, -0.57317099, -0.50499728]),
#    'avg_score': -0.5485063779355587,
#    'feature_names': ('value.Installation',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Transportation'),
#    'ci_bound': 0.08986111254872986,
#    'std_dev': 0.06991499844025205,
#    'std_err': 0.03495749922012602},
#   17: {'feature_idx': (20,
#     24,
#     26,
#     33,
#     46,
#     48,
#     50,
#     51,
#     58,
#     76,
#     77,
#     78,
#     82,
#     84,
#     102,
#     103,
#     119),
#    'cv_scores': array([-0.53747985, -0.46246902, -0.6734462 , -0.57298472, -0.50592137]),
#    'avg_score': -0.5504602318030368,
#    'feature_names': ('value.Installation',
#     'value.Equipment Maintenance',
#     'value.Repairing',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Transportation'),
#    'ci_bound': 0.09183771208076232,
#    'std_dev': 0.07145286002775589,
#    'std_err': 0.035726430013877944},
#   18: {'feature_idx': (21,
#     24,
#     25,
#     31,
#     46,
#     48,
#     50,
#     58,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.55531297, -0.47145452, -0.68619124, -0.55521791, -0.48277013]),
#    'avg_score': -0.5501893567014727,
#    'feature_names': ('value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Finger Dexterity',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.09837737426403746,
#    'std_dev': 0.07654093938016225,
#    'std_err': 0.038270469690081126},
#   19: {'feature_idx': (9,
#     21,
#     24,
#     25,
#     31,
#     46,
#     48,
#     50,
#     58,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.55382223, -0.458192  , -0.6790548 , -0.57858878, -0.48641046]),
#    'avg_score': -0.5512136526741067,
#    'feature_names': ('value.Monitoring',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Finger Dexterity',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.09947859982794598,
#    'std_dev': 0.0773977302811349,
#    'std_err': 0.038698865140567446},
#   20: {'feature_idx': (9,
#     20,
#     21,
#     24,
#     25,
#     31,
#     46,
#     48,
#     50,
#     51,
#     58,
#     76,
#     77,
#     78,
#     80,
#     81,
#     84,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.5534262 , -0.46079991, -0.67955414, -0.57405032, -0.48898654]),
#    'avg_score': -0.5513634219770203,
#    'feature_names': ('value.Monitoring',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.0979598034554201,
#    'std_dev': 0.07621605510480516,
#    'std_err': 0.03810802755240257},
#   21: {'feature_idx': (9,
#     21,
#     24,
#     25,
#     26,
#     31,
#     46,
#     48,
#     50,
#     51,
#     58,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.56023218, -0.45419301, -0.67475164, -0.57369004, -0.49731806]),
#    'avg_score': -0.5520369854081421,
#    'feature_names': ('value.Monitoring',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Repairing',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.09646107244357091,
#    'std_dev': 0.07504999146076811,
#    'std_err': 0.03752499573038406},
#   22: {'feature_idx': (9,
#     21,
#     24,
#     25,
#     26,
#     31,
#     46,
#     48,
#     50,
#     51,
#     58,
#     59,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.55616262, -0.45776109, -0.68678068, -0.56628194, -0.49742478]),
#    'avg_score': -0.552882222325098,
#    'feature_names': ('value.Monitoring',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Repairing',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.09996005707232734,
#    'std_dev': 0.07777232037394859,
#    'std_err': 0.03888616018697429},
#   23: {'feature_idx': (9,
#     20,
#     21,
#     24,
#     25,
#     26,
#     31,
#     46,
#     48,
#     50,
#     51,
#     58,
#     59,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.56049642, -0.46201659, -0.68362083, -0.5749675 , -0.5010851 ]),
#    'avg_score': -0.556437288081644,
#    'feature_names': ('value.Monitoring',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Repairing',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.09706224495765975,
#    'std_dev': 0.07551772410053541,
#    'std_err': 0.037758862050267704},
#   24: {'feature_idx': (9,
#     20,
#     21,
#     24,
#     25,
#     26,
#     28,
#     31,
#     46,
#     48,
#     50,
#     51,
#     58,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     92,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.55855483, -0.46241352, -0.68689426, -0.57719523, -0.50084307]),
#    'avg_score': -0.5571801828541998,
#    'feature_names': ('value.Monitoring',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Repairing',
#     'value.Judgment and Decision Making',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Personnel and Human Resources',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.0985288046682817,
#    'std_dev': 0.07665875737925282,
#    'std_err': 0.03832937868962641},
#   25: {'feature_idx': (9,
#     20,
#     21,
#     24,
#     25,
#     26,
#     31,
#     46,
#     48,
#     50,
#     51,
#     58,
#     59,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     92,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.55695097, -0.47353163, -0.68046104, -0.57265908, -0.50494922]),
#    'avg_score': -0.557710387637084,
#    'feature_names': ('value.Monitoring',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Repairing',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Finger Dexterity',
#     'value.Control Precision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Personnel and Human Resources',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.09117699456088427,
#    'std_dev': 0.07093879935054503,
#    'std_err': 0.03546939967527252},
#   26: {'feature_idx': (9,
#     20,
#     21,
#     24,
#     25,
#     26,
#     28,
#     31,
#     46,
#     48,
#     50,
#     51,
#     52,
#     58,
#     63,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     84,
#     92,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.55836705, -0.46803308, -0.68333336, -0.57691655, -0.51031056]),
#    'avg_score': -0.5593921199010629,
#    'feature_names': ('value.Monitoring',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Repairing',
#     'value.Judgment and Decision Making',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
#     'value.Finger Dexterity',
#     'value.Reaction Time',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Sound Localization',
#     'value.Personnel and Human Resources',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.09343819553259339,
#    'std_dev': 0.07269809052696365,
#    'std_err': 0.036349045263481816},
#   27: {'feature_idx': (9,
#     20,
#     21,
#     24,
#     25,
#     26,
#     28,
#     31,
#     46,
#     48,
#     50,
#     51,
#     52,
#     58,
#     61,
#     63,
#     76,
#     77,
#     78,
#     79,
#     80,
#     81,
#     82,
#     84,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.56251626, -0.46404639, -0.68870768, -0.5687267 , -0.50983064]),
#    'avg_score': -0.5587655356923047,
#    'feature_names': ('value.Monitoring',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Repairing',
#     'value.Judgment and Decision Making',
#     'value.Time Management',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
#     'value.Finger Dexterity',
#     'value.Response Orientation',
#     'value.Reaction Time',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Peripheral Vision',
#     'value.Depth Perception',
#     'value.Glare Sensitivity',
#     'value.Hearing Sensitivity',
#     'value.Sound Localization',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation'),
#    'ci_bound': 0.0968065454837343,
#    'std_dev': 0.07531878122286988,
#    'std_err': 0.03765939061143494},
#   28: {'feature_idx': (9,
#     18,
#     20,
#     21,
#     24,
#     25,
#     26,
#     28,
#     31,
#     33,
#     46,
#     48,
#     50,
#     51,
#     52,
#     58,
#     63,
#     72,
#     76,
#     77,
#     78,
#     79,
#     80,
#     82,
#     84,
#     101,
#     102,
#     119),
#    'cv_scores': array([-0.56508354, -0.48072877, -0.68016888, -0.56174402, -0.51243435]),
#    'avg_score': -0.5600319150848703,
#    'feature_names': ('value.Monitoring',
#     'value.Technology Design',
#     'value.Installation',
#     'value.Programming',
#     'value.Equipment Maintenance',
#     'value.Troubleshooting',
#     'value.Repairing',
#     'value.Judgment and Decision Making',
#     'value.Time Management',
#     'value.Management of Material Resources',
#     'value.Mathematical Reasoning',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Spatial Orientation',
# ...
#     'value.Systems Evaluation',
#     'value.Management of Financial Resources',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Time Sharing',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08639999626698876,
#    'std_dev': 0.0672221323875617,
#    'std_err': 0.03361106619378085},
#   18: {'feature_idx': (9,
#     10,
#     30,
#     32,
#     48,
#     50,
#     54,
#     58,
#     68,
#     75,
#     76,
#     77,
#     78,
#     92,
#     95,
#     102,
#     103,
#     120),
#    'cv_scores': array([-0.54256785, -0.45815155, -0.65774077, -0.55546675, -0.48962552]),
#    'avg_score': -0.5407104854103466,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Systems Evaluation',
#     'value.Management of Financial Resources',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Selective Attention',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Chemistry',
#     'value.Biology',
#     'work_num'),
#    'ci_bound': 0.08782015069460736,
#    'std_dev': 0.06832706077956252,
#    'std_err': 0.03416353038978125},
#   19: {'feature_idx': (9,
#     10,
#     16,
#     30,
#     32,
#     48,
#     50,
#     54,
#     58,
#     68,
#     75,
#     76,
#     77,
#     78,
#     92,
#     95,
#     102,
#     103,
#     120),
#    'cv_scores': array([-0.54886278, -0.45740615, -0.66148076, -0.54939561, -0.4942842 ]),
#    'avg_score': -0.5422859009543833,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Complex Problem Solving',
#     'value.Systems Evaluation',
#     'value.Management of Financial Resources',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Selective Attention',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Visual Color Discrimination',
#     'value.Night Vision',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Chemistry',
#     'value.Biology',
#     'work_num'),
#    'ci_bound': 0.08869430163072667,
#    'std_dev': 0.0690071799056437,
#    'std_err': 0.03450358995282185},
#   20: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     32,
#     44,
#     48,
#     50,
#     55,
#     58,
#     68,
#     75,
#     76,
#     78,
#     92,
#     95,
#     102,
#     103,
#     119,
#     120),
#    'cv_scores': array([-0.53948896, -0.47733013, -0.66086164, -0.53813363, -0.49193327]),
#    'avg_score': -0.5415495250930076,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Management of Financial Resources',
#     'value.Information Ordering',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Time Sharing',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Night Vision',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08297286751830284,
#    'std_dev': 0.0645557097902565,
#    'std_err': 0.03227785489512825},
#   21: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     39,
#     42,
#     44,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     95,
#     102,
#     103,
#     119,
#     120),
#    'cv_scores': array([-0.53650366, -0.47304922, -0.65914602, -0.53116137, -0.50391215]),
#    'avg_score': -0.5407544831986127,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Fluency of Ideas',
#     'value.Deductive Reasoning',
#     'value.Information Ordering',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Computers and Electronics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08142703481314859,
#    'std_dev': 0.0633529994286288,
#    'std_err': 0.0316764997143144},
#   22: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     39,
#     42,
#     44,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     95,
#     102,
#     103,
#     119,
#     120),
#    'cv_scores': array([-0.53693206, -0.47912775, -0.65735887, -0.53608935, -0.5036954 ]),
#    'avg_score': -0.5426406864366478,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Fluency of Ideas',
#     'value.Deductive Reasoning',
#     'value.Information Ordering',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Computers and Electronics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.07878403335511028,
#    'std_dev': 0.0612966545028287,
#    'std_err': 0.03064832725141435},
#   23: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     39,
#     42,
#     44,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     85,
#     95,
#     102,
#     103,
#     119,
#     120),
#    'cv_scores': array([-0.53607732, -0.47928229, -0.65899587, -0.5350063 , -0.50925992]),
#    'avg_score': -0.5437243403125069,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Fluency of Ideas',
#     'value.Deductive Reasoning',
#     'value.Information Ordering',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Speech Recognition',
#     'value.Computers and Electronics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.0787340743260449,
#    'std_dev': 0.06125778468094342,
#    'std_err': 0.030628892340471715},
#   24: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     33,
#     39,
#     42,
#     44,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     85,
#     92,
#     95,
#     102,
#     119,
#     120),
#    'cv_scores': array([-0.53659978, -0.47951119, -0.66704368, -0.53680439, -0.50480795]),
#    'avg_score': -0.5449534007159141,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Management of Material Resources',
#     'value.Fluency of Ideas',
#     'value.Deductive Reasoning',
#     'value.Information Ordering',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Speech Recognition',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Chemistry',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08317046825225312,
#    'std_dev': 0.06470944987441621,
#    'std_err': 0.032354724937208104},
#   25: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     33,
#     39,
#     42,
#     44,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     85,
#     92,
#     95,
#     101,
#     102,
#     119,
#     120),
#    'cv_scores': array([-0.53973724, -0.48121059, -0.66890773, -0.53312382, -0.50532462]),
#    'avg_score': -0.5456607978965728,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Management of Material Resources',
#     'value.Fluency of Ideas',
#     'value.Deductive Reasoning',
#     'value.Information Ordering',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Speech Recognition',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08361883197168772,
#    'std_dev': 0.06505829208052553,
#    'std_err': 0.03252914604026276},
#   26: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     33,
#     39,
#     44,
#     45,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     85,
#     92,
#     95,
#     101,
#     102,
#     103,
#     119,
#     120),
#    'cv_scores': array([-0.5386835 , -0.48125238, -0.67020574, -0.5348963 , -0.50611171]),
#    'avg_score': -0.5462299250368785,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Management of Material Resources',
#     'value.Fluency of Ideas',
#     'value.Information Ordering',
#     'value.Category Flexibility',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Speech Recognition',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08406029565209652,
#    'std_dev': 0.06540176582185575,
#    'std_err': 0.032700882910927875},
#   27: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     33,
#     39,
#     44,
#     45,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     85,
#     92,
#     95,
#     101,
#     102,
#     103,
#     111,
#     119,
#     120),
#    'cv_scores': array([-0.54206719, -0.48224751, -0.66485978, -0.5387756 , -0.50462564]),
#    'avg_score': -0.546515143042531,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Management of Material Resources',
#     'value.Fluency of Ideas',
#     'value.Information Ordering',
#     'value.Category Flexibility',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Speech Recognition',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Foreign Language',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08122834833081893,
#    'std_dev': 0.06319841459534352,
#    'std_err': 0.03159920729767175},
#   28: {'feature_idx': (9,
#     10,
#     15,
#     30,
#     33,
#     36,
#     39,
#     44,
#     45,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     85,
#     92,
#     95,
#     101,
#     102,
#     103,
#     111,
#     119,
#     120),
#    'cv_scores': array([-0.53708659, -0.47837366, -0.67007299, -0.54185542, -0.51250788]),
#    'avg_score': -0.547979307463697,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Management of Material Resources',
#     'value.Written Comprehension',
#     'value.Fluency of Ideas',
#     'value.Information Ordering',
#     'value.Category Flexibility',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Speech Recognition',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Foreign Language',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08362531939703095,
#    'std_dev': 0.06506333951784171,
#    'std_err': 0.032531669758920856},
#   29: {'feature_idx': (9,
#     10,
#     14,
#     15,
#     30,
#     33,
#     36,
#     39,
#     44,
#     45,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     85,
#     92,
#     95,
#     101,
#     102,
#     103,
#     111,
#     119,
#     120),
#    'cv_scores': array([-0.54216114, -0.48918689, -0.66645227, -0.54175622, -0.50419945]),
#    'avg_score': -0.5487511960333032,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Instructing',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Management of Material Resources',
#     'value.Written Comprehension',
#     'value.Fluency of Ideas',
#     'value.Information Ordering',
#     'value.Category Flexibility',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Speech Recognition',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Foreign Language',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08022247256165738,
#    'std_dev': 0.062415809074029924,
#    'std_err': 0.03120790453701496},
#   30: {'feature_idx': (9,
#     10,
#     13,
#     14,
#     15,
#     30,
#     33,
#     36,
#     39,
#     44,
#     45,
#     48,
#     50,
#     51,
#     55,
#     56,
#     58,
#     68,
#     75,
#     76,
#     79,
#     85,
#     92,
#     95,
#     101,
#     102,
#     103,
#     111,
#     119,
#     120),
#    'cv_scores': array([-0.54686891, -0.49062035, -0.66907636, -0.54190114, -0.50300344]),
#    'avg_score': -0.5502940409439485,
#    'feature_names': ('value.Monitoring',
#     'value.Social Perceptiveness',
#     'value.Negotiation',
#     'value.Instructing',
#     'value.Service Orientation',
#     'value.Systems Evaluation',
#     'value.Management of Material Resources',
#     'value.Written Comprehension',
#     'value.Fluency of Ideas',
#     'value.Information Ordering',
#     'value.Category Flexibility',
#     'value.Memorization',
#     'value.Flexibility of Closure',
#     'value.Perceptual Speed',
#     'value.Time Sharing',
#     'value.Arm-Hand Steadiness',
#     'value.Finger Dexterity',
#     'value.Dynamic Strength',
#     'value.Near Vision',
#     'value.Far Vision',
#     'value.Peripheral Vision',
#     'value.Speech Recognition',
#     'value.Personnel and Human Resources',
#     'value.Computers and Electronics',
#     'value.Physics',
#     'value.Chemistry',
#     'value.Biology',
#     'value.Foreign Language',
#     'value.Transportation',
#     'work_num'),
#    'ci_bound': 0.08126609368211361,
#    'std_dev': 0.06322778176098441,
#    'std_err': 0.031613890880492206}}]
